# %% [markdown]
# # Fine-tuning Qwen 2.5 for Medical SOAP Note Generation
# - This notebook demonstrates how to fine-tune Qwen 2.5 (1.5B parameter model) to generate medical SOAP notes from doctor-patient dialogues.
# - SOAP notes are structured medical documentation including Subjective, Objective, Assessment, and Plan sections.

# %% [markdown]
# # Setup Environment
#   First, we'll mount Google Drive, install required packages, and set up our environment.

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Install required packages
# !pip install -qU transformers==4.48.3 datasets==3.2.0 optimum==1.24.0
# !pip install -qU openai==1.61.0 wandb
# !pip install -qU json-repair==0.29.1
# !pip install -qU faker==35.2.0
#!pip install -qU vllm==0.7.2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 70.3 MB/s eta 0:00:00

# %%
# Clone LLaMA-Factory
# !git clone --depth 1 https://github.com/hiyouga/LLaMA-Factory.git
# !cd LLaMA-Factory && pip install -e .
# Out:
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 357, done.
# remote: Counting objects: 100% (357/357), done.
# remote: Compressing objects: 100% (276/276), done.
# remote: Total 357 (delta 76), reused 304 (delta 66), pack-reused 0 (from 0)
# Receiving objects: 100% (357/357), 9.64 MiB | 7.29 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.51.3,>=4.45.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (4.48.3)
# Requirement already satisfied: datasets<=3.5.0,>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (3.2.0)
# Requirement already satisfied: accelerate<=1.6.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (1.6.0)
# Collecting peft<=0.15.1,>=0.14.0 (from llamafactory==0.9.3.dev0)
#   Downloading peft-0.15.1-py3-none-any.whl.metadata (13 kB)
# Collecting trl<=0.9.6,>=0.8.6 (from llamafactory==0.9.3.dev0)
#   Downloading trl-0.9.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tokenizers<=0.21.1,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.21.1)
# Collecting gradio<=5.25.0,>=4.38.0 (from llamafactory==0.9.3.dev0)
#   Downloading gradio-5.25.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (1.15.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.2.0)
# Collecting tiktoken (from llamafactory==0.9.3.dev0)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (5.29.4)
# Collecting uvicorn (from llamafactory==0.9.3.dev0)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting fastapi (from llamafactory==0.9.3.dev0)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting sse-starlette (from llamafactory==0.9.3.dev0)
#   Downloading sse_starlette-2.3.4-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (3.10.0)
# Collecting fire (from llamafactory==0.9.3.dev0)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting omegaconf (from llamafactory==0.9.3.dev0)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (6.0.2)
# Collecting numpy<2.0.0 (from llamafactory==0.9.3.dev0)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.0 MB/s eta 0:00:00
# Collecting pydantic<=2.10.6 (from llamafactory==0.9.3.dev0)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (2.2.2)
# Collecting av (from llamafactory==0.9.3.dev0)
#   Downloading av-14.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.11.0)
# Collecting tyro<0.9.0 (from llamafactory==0.9.3.dev0)
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.11.15)
# Collecting aiofiles<25.0,>=22.0 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (4.9.0)
# Collecting ffmpy (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.8.0 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading gradio_client-1.8.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.10.18)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (11.2.1)
# Collecting pydub (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.9.3 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading ruff-0.11.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (0.15.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (4.13.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.8.0->gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (15.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->llamafactory==0.9.3.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->llamafactory==0.9.3.dev0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<=2.10.6->llamafactory==0.9.3.dev0) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic<=2.10.6->llamafactory==0.9.3.dev0)
#   Downloading pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,<=4.51.3,>=4.45.0->llamafactory==0.9.3.dev0) (2024.11.6)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->llamafactory==0.9.3.dev0) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->llamafactory==0.9.3.dev0) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro<0.9.0->llamafactory==0.9.3.dev0)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llamafactory==0.9.3.dev0) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llamafactory==0.9.3.dev0) (0.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire->llamafactory==0.9.3.dev0) (3.1.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.1.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->llamafactory==0.9.3.dev0)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (1.20.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (1.0.9)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->llamafactory==0.9.3.dev0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->llamafactory==0.9.3.dev0) (4.3.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets<=3.5.0,>=2.16.0->llamafactory==0.9.3.dev0) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.3.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.3.dev0) (2.19.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa->llamafactory==0.9.3.dev0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->llamafactory==0.9.3.dev0) (1.17.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate<=1.6.0,>=0.34.0->llamafactory==0.9.3.dev0) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio<=5.25.0,>=4.38.0->llamafactory==0.9.3.dev0) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->llamafactory==0.9.3.dev0) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.3.dev0) (0.1.2)
# Downloading gradio-5.25.0-py3-none-any.whl (46.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 15.7 MB/s eta 0:00:00
# Downloading gradio_client-1.8.0-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 25.6 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 76.9 MB/s eta 0:00:00
# Downloading peft-0.15.1-py3-none-any.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.0/411.0 kB 17.3 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 35.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.2 MB/s eta 0:00:00
# Downloading trl-0.9.6-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 23.3 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 10.7 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.4 MB/s eta 0:00:00
# Downloading av-14.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 16.7 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.1 MB/s eta 0:00:00
# Downloading sse_starlette-2.3.4-py3-none-any.whl (10 kB)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.0 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 73.3 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.2 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Building wheels for collected packages: llamafactory, fire, antlr4-python3-runtime
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.3.dev0-0.editable-py3-none-any.whl size=26934 sha256=025902d17a7ecbcc594a26423062c1701d2601dd7a1c6fbe5372a150de9bd56e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4ddduexh/wheels/bd/34/05/1e3cb4b8f20c20631b411dc5157b4b150850c03496fa96c2c4
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=3c27296dd5bbd9e8ebb0a8464855958bc1418bd67530a1289fd3cdfa403ebab1
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=4a48b8fed83c6036fff15d1a89959f13127fb9f9010dcc5238bd6f0579fda531
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built llamafactory fire antlr4-python3-runtime
# Installing collected packages: pydub, antlr4-python3-runtime, uvicorn, tomlkit, shtab, semantic-version, ruff, python-multipart, pydantic-core, omegaconf, numpy, groovy, fire, ffmpy, av, aiofiles, tiktoken, starlette, pydantic, tyro, sse-starlette, safehttpx, gradio-client, fastapi, gradio, trl, peft, llamafactory
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.4
#     Uninstalling pydantic-2.11.4:
#       Successfully uninstalled pydantic-2.11.4
#   Attempting uninstall: peft
#     Found existing installation: peft 0.15.2
#     Uninstalling peft-0.15.2:
#       Successfully uninstalled peft-0.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed aiofiles-24.1.0 antlr4-python3-runtime-4.9.3 av-14.3.0 fastapi-0.115.12 ffmpy-0.5.0 fire-0.7.0 gradio-5.25.0 gradio-client-1.8.0 groovy-0.1.2 llamafactory-0.9.3.dev0 numpy-1.26.4 omegaconf-2.3.0 peft-0.15.1 pydantic-2.10.6 pydantic-core-2.27.2 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.8 safehttpx-0.1.6 semantic-version-2.10.0 shtab-1.7.2 sse-starlette-2.3.4 starlette-0.46.2 tiktoken-0.9.0 tomlkit-0.13.2 trl-0.9.6 tyro-0.8.14 uvicorn-0.34.2

# %% [markdown]
# # Authentication Setup
# We'll set up authentication for Weights & Biases (for experiment tracking) and Hugging Face (for model downloading and uploading).

# %%
# Login to WandB and HuggingFace
from google.colab import userdata
import wandb

wandb.login(key=userdata.get('wandb'))
hf_token = userdata.get('huggingface')
# !huggingface-cli login --token {hf_token}
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: hazemwalied2003 (hazemwalied2003-cairo-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# The token `notebooks_token` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `notebooks_token`

# %% [markdown]
# # Import Libraries
# Now we'll import the essential libraries for our fine-tuning process.

# %%
import json
import os
from os.path import join
import random
from tqdm.auto import tqdm
import requests

from pydantic import BaseModel, Field
from typing import List, Optional, Literal
from datetime import datetime

import json_repair

from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

# Set directories and model
data_dir = "/gdrive/MyDrive/qwen-finetune-v2"
base_model_id = "Qwen/Qwen2.5-1.5B-Instruct"

device = "cuda"
torch_dtype = None

# %% [markdown]
# # Data Loading and Preparation
# We'll load the medical dialogue dataset and format it for fine-tuning.

# %%
# Helper function to parse JSON
def parse_json(text):
    try:
        return json_repair.loads(text)
    except:
        return None

# Load dataset
from datasets import load_dataset, concatenate_datasets

dataset = load_dataset("omi-health/medical-dialogue-to-soap-summary")

# Combine train and test for simpler handling
dataset['train'] = concatenate_datasets([dataset['train'], dataset['test']])
dataset['train'] = concatenate_datasets([dataset['train'], dataset['validation']])
dataset.pop('test')
dataset.pop('validation')

print(f"Total samples in dataset: {len(dataset['train'])}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/2.15k [00:00<?, ?B/s]
# train.json:   0%|          | 0.00/154M [00:00<?, ?B/s]
# validation.json:   0%|          | 0.00/8.31M [00:00<?, ?B/s]
# test.json:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9250 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/500 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/250 [00:00<?, ? examples/s]
# Total samples in dataset: 10000

# %% [markdown]
# # Define SOAP Summary Task
# We'll use Pydantic to create a schema for our SOAP notes, which will help structure the model's output.

# %%
class SOAPSummary(BaseModel):
    subjective: str = Field(...,
                           description="Patient's subjective experiences, symptoms, and concerns as reported in the dialogue.")
    objective: str = Field(...,
                          description="Objective medical findings, vital signs, and examination results mentioned in the dialogue.")
    assessment: str = Field(...,
                           description="Clinician's assessment and diagnosis of the patient's condition based on the dialogue.")
    plan: str = Field(...,
                     description="Treatment plan, medications, follow-up instructions, and recommendations discussed in the dialogue.")

# %% [markdown]
# # Prepare Training Data
# Now we'll format the dataset for fine-tuning with the LLaMA-Factory framework.

# %%
# Create directory if it doesn't exist
os.makedirs(join(data_dir, "datasets", "llamafactory-finetune-data"), exist_ok=True)

# %%
# Format Dataset for Fine-tuning with JSON structure
llm_finetunning_data = []

system_message = "\n".join([
    "You are a medical professional tasked with creating structured SOAP notes from patient-doctor dialogues.",
    "Generate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.",
    "Your summary should be concise yet comprehensive, capturing all relevant medical information.",
    "Output must be in valid JSON format according to the provided schema.",
    "Do not include any text outside the JSON structure."
])

# Process dataset
for i, entry in enumerate(tqdm(dataset['train'])):
    dialogue = entry['dialogue']
    soap_summary = entry['soap']

    components = {}

    if "S:" in soap_summary and "O:" in soap_summary:
        s_text = soap_summary.split("S:")[1].split("O:")[0].strip()
        components["subjective"] = s_text

    if "O:" in soap_summary and "A:" in soap_summary:
        o_text = soap_summary.split("O:")[1].split("A:")[0].strip()
        components["objective"] = o_text

    if "A:" in soap_summary and "P:" in soap_summary:
        a_text = soap_summary.split("A:")[1].split("P:")[0].strip()
        components["assessment"] = a_text

    if "P:" in soap_summary:
        p_text = soap_summary.split("P:")[1].strip()
        components["plan"] = p_text

    # If we couldn't parse properly, use placeholders to prevent errors
    if "subjective" not in components:
        components["subjective"] = "Information not available"
    if "objective" not in components:
        components["objective"] = "Information not available"
    if "assessment" not in components:
        components["assessment"] = "Information not available"
    if "plan" not in components:
        components["plan"] = "Information not available"

    # Create JSON output for training
    json_output = json.dumps(components, ensure_ascii=False)

    llm_finetunning_data.append({
        "system": system_message,
        "instruction": "\n".join([
            "# Patient-Doctor Dialogue:",
            dialogue,
            "",
            "# Task:",
            "Generate a structured SOAP summary from the above medical dialogue.",
            "The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.",
            "",
            "# JSON Schema:",
            json.dumps(SOAPSummary.model_json_schema(), ensure_ascii=False),
            "",
            "# SOAP Summary:",
            "```json"
        ]),
        "input": "",
        "output": json_output + "\n```",
        "history": []
    })
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %% [markdown]
# # Examine Sample Data
# Let's look at a sample from our dataset to understand what we're working with.

# %%
print(dataset['train'][121]['soap'])
# Out:
# S: The patient, with a history of chronic obstructive pulmonary disease (COPD), presents with shortness of breath and a productive cough. He reports worsening dyspnea and a productive cough eight weeks post initial admission.
# O: Initial CT angiogram revealed spiculated nodules in bilateral lower lobes and right hilar lymphadenopathy. Pathology confirmed a moderately differentiated nonkeratinizing squamous cell carcinoma of the left lung nodule and highly atypical large lymphocytes in the right lymph node, suggestive of large B-cell lymphoma. Recent CT chest with contrast showed a large, centrally necrotic mass measuring 18.1 cm x 8 cm. Vital signs indicate hemodynamic stability with no increased oxygen requirements, but physical exam shows facial swelling, jugular venous distention, diffuse wheezing, bilateral basal crackles, and bilateral pitting pedal edema.
# A: Primary diagnosis of squamous cell carcinoma of the lung with concurrent large B-cell lymphoma. Differential diagnosis includes complications from COPD and potential metastasis or progression of known malignancies. Prognosis is guarded given the advanced nature of malignancies and COPD.
# P: Continued supplemental oxygen therapy at 3 L/min via nasal cannula. Initiated IV furosemide for peripheral edema and prednisone 50 mg daily for acute COPD exacerbation. Referral to radiation oncology for cancer management and planned lymph node excision biopsy to confirm lymphoma diagnosis. Advised follow-up with radiation oncologist and monitoring for symptom progression. Adjustments to the treatment plan will be made based on ongoing assessments and response to therapy.

# %%
print(llm_finetunning_data[121])
# Out:
# {'system': 'You are a medical professional tasked with creating structured SOAP notes from patient-doctor dialogues.\nGenerate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.\nYour summary should be concise yet comprehensive, capturing all relevant medical information.\nOutput must be in valid JSON format according to the provided schema.\nDo not include any text outside the JSON structure.', 'instruction': '# Patient-Doctor Dialogue:\nDoctor: Hello, can you tell me about your past medical history? Have you been diagnosed with any chronic conditions?\nPatient: Yes, I have chronic obstructive pulmonary disease (COPD).\nDoctor: I see. What brings you here today?\nPatient: I\'ve been feeling short of air and have had a productive cough.\nDoctor: Alright, we\'ll need to do a CT angiogram to check for pulmonary embolism. We\'ll also look for any other abnormalities in your lungs.\n(CT Angiogram results)\nDoctor: The CT angiogram showed spiculated nodules in your bilateral lower lobes. The right nodule measures 1.1 cm x 0.9 cm, and the left one measures 1.5 cm x 1.2 cm. There\'s also right hilar lymphadenopathy, with the largest lymph node measuring 2.9 cm x 2.1 cm. No mediastinal or axillary lymphadenopathy was noted, but there are emphysematous changes in your lungs.\nPatient: Oh, okay.\nDoctor: We performed a biopsy of the left lung nodule and a right lymph node fine needle aspiration (FNA) to further investigate these findings.\n(Pathology results)\nDoctor: The pathology results showed that the left lung nodule is a moderately differentiated nonkeratinizing squamous cell carcinoma. The cytology studies on the right lymph node sample revealed highly atypical large lymphocytes with 95% monoclonal B-cells on flow cytometry, which is concerning for large B-cell lymphoma.\nPatient: That sounds serious.\nDoctor: After stabilizing your respiratory condition, we discharged you with supplemental oxygen therapy via nasal cannula at three liters/minute (L/min). Your case was discussed in a multi-disciplinary tumor board, and the cardio-thoracic surgery team felt that you were not a candidate for lobectomy. Instead, they recommended radiation therapy, and we made a referral to radiation oncology. We also planned a lymph node excision biopsy to establish a definite diagnosis of lymphoma.\nPatient: Okay, I understand.\nDoctor: About eight weeks after your initial admission, you presented with worsening dyspnea and a productive cough. You were hemodynamically stable, with no increase in supplemental oxygen requirements. However, you had facial swelling, jugular venous distention, diffuse wheezing with bilateral basal crackles, and bilateral pitting pedal edema.\nPatient: Yeah, I\'ve been feeling worse.\nDoctor: We started treatment for an acute COPD exacerbation. We administered intravenous (IV) furosemide for your peripheral edema and prescribed prednisone 50 mg daily. We also performed a CT chest with contrast to monitor your condition.\nPatient: What did the CT show?\nDoctor: The CT showed a large, centrally necrotic mass measuring 18.1 cm x 8 cm. We\'ll continue to monitor your condition and adjust your treatment plan as necessary. Please follow up with your radiation oncologist and let us know if your symptoms worsen.\nPatient: Okay, thank you for the information.\n\n# Task:\nGenerate a structured SOAP summary from the above medical dialogue.\nThe summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.\n\n# JSON Schema:\n{"properties": {"subjective": {"description": "Patient\'s subjective experiences, symptoms, and concerns as reported in the dialogue.", "title": "Subjective", "type": "string"}, "objective": {"description": "Objective medical findings, vital signs, and examination results mentioned in the dialogue.", "title": "Objective", "type": "string"}, "assessment": {"description": "Clinician\'s assessment and diagnosis of the patient\'s condition ba ...

# %% [markdown]
# # Split Dataset
# We'll split our dataset into training and evaluation sets.

# %%
# Shuffle data with a fixed seed for reproducibility
random.Random(101).shuffle(llm_finetunning_data)

# Split into train and evaluation sets (90/10 split)
train_ratio = 0.9
train_size = int(len(llm_finetunning_data) * train_ratio)

train_ds = llm_finetunning_data[:train_size]
eval_ds = llm_finetunning_data[train_size:]

print(f"Training samples: {len(train_ds)}")
print(f"Evaluation samples: {len(eval_ds)}")
# Out:
# Training samples: 9000
# Evaluation samples: 1000

# %%
# Save datasets
with open(join(data_dir, "datasets", "llamafactory-finetune-data", "train.json"), "w", encoding="utf8") as dest:
    json.dump(train_ds, dest, ensure_ascii=False)

with open(join(data_dir, "datasets", "llamafactory-finetune-data", "val.json"), "w", encoding="utf8") as dest:
    json.dump(eval_ds, dest, ensure_ascii=False)

print(f"Datasets saved to {join(data_dir, 'datasets', 'llamafactory-finetune-data')}")
# Out:
# Datasets saved to /gdrive/MyDrive/qwen-finetune-v2/datasets/llamafactory-finetune-data

# %% [markdown]
# # Test Base Model
# Before fine-tuning, let's test the base model's capabilities on our task.

# %%
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    device_map="auto",
    torch_dtype=torch_dtype
)

tokenizer = AutoTokenizer.from_pretrained(base_model_id)
# Out:
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]

# %%
# Test with a sample
sample_dialogue = dataset['train'][121]['dialogue']
print("Sample dialogue:\n", sample_dialogue[:300], "...\n")

# Create system message that emphasizes JSON output
system_message = "\n".join([
    "You are a medical professional tasked with creating structured SOAP notes from patient-doctor dialogues.",
    "Generate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.",
    "Your summary should be concise yet comprehensive, capturing all relevant medical information.",
    "Output must be in valid JSON format according to the provided schema.",
    "Do not include any text outside the JSON structure."
])

# Create testing prompt with JSON schema
sample_messages = [
    {
        "role": "system",
        "content": system_message
    },
    {
        "role": "user",
        "content": "\n".join([
            "# Patient-Doctor Dialogue:",
            sample_dialogue,
            "",
            "# Task:",
            "Generate a structured SOAP summary from the above medical dialogue.",
            "The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.",
            "",
            "# JSON Schema:",
            json.dumps(SOAPSummary.model_json_schema(), ensure_ascii=False),
            "",
            "# SOAP Summary:",
            "```json"
        ])
    }
]

# Apply chat template
text = tokenizer.apply_chat_template(
    sample_messages,
    tokenize=False,
    add_generation_prompt=True
)

# Generate response
model_inputs = tokenizer([text], return_tensors="pt", padding=True).to(device)

generated_ids = model.generate(
    model_inputs.input_ids,
    max_new_tokens=1024,
    do_sample=False,
    temperature=0.1,
    repetition_penalty=1.1
)

generated_ids = [
    output_ids[len(input_ids):]
    for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
print("Model response preview:")
print(response)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.8` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:650: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `20` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Sample dialogue:
#  Doctor: Hello, can you tell me about your past medical history? Have you been diagnosed with any chronic conditions?
# Patient: Yes, I have chronic obstructive pulmonary disease (COPD).
# Doctor: I see. What brings you here today?
# Patient: I've been feeling short of air and have had a productive cough.
#  ...
#
# Model response preview:
# {
#   "subjective": "Patient reports feeling short of breath and having a productive cough.",
#   "objective": "CT angiogram shows spiculated nodules in bilateral lower lobes, right hilar lymphadenopathy, and emphysematous changes in lungs; pathology results indicate a moderately differentiated nonkeratinizing squamous cell carcinoma in the left lung nodule and highly atypical large lymphocytes with 95% monoclonal B-cells in the right lymph node.",
#   "assessment": "The patient has a history of COPD, and recent imaging suggests malignancy involving both the lung and lymph nodes. Further evaluation through biopsy and consultation with radiation oncology is needed.",
#   "plan": "Discharged with supplemental oxygen therapy, initiated IV furosemide for peripheral edema, and scheduled for a CT chest with contrast monitoring. Follow-up with radiation oncology for further management."
# }

# %% [markdown]
# # Validate Model Output
# Now we'll check if the model's output conforms to our JSON schema.

# %%
print("\nAttempting to parse JSON response:")
try:
    # Find JSON block if the model wrapped it with ```json and ```
    if "```json" in response and "```" in response.split("```json", 1)[1]:
        json_str = response.split("```json", 1)[1].split("```", 1)[0].strip()
    else:
        # If no code blocks, try to parse the whole response
        json_str = response.strip()

    # Clean up any trailing commas that might cause parsing errors
    json_str = json_str.replace(",\n}", "\n}")
    json_str = json_str.replace(",\n]", "\n]")

    parsed_json = json_repair.loads(json_str)
    print("Successfully parsed JSON:")
    print(json.dumps(parsed_json, indent=2))

    try:
        soap_summary = SOAPSummary(**parsed_json)
        print("\nValidation successful! All required fields are present.")
    except Exception as e:
        print(f"\nValidation error: {e}")
        print("JSON does not match the expected schema.")

except Exception as e:
    print(f"Failed to parse JSON: {e}")
    print("Raw response may not contain valid JSON.")

# Add a function to properly format SOAP
def format_soap_display(soap_dict):
    """Format SOAP dictionary into readable text format"""
    formatted = []
    if "subjective" in soap_dict:
        formatted.append(f"S: {soap_dict['subjective']}")
    if "objective" in soap_dict:
        formatted.append(f"O: {soap_dict['objective']}")
    if "assessment" in soap_dict:
        formatted.append(f"A: {soap_dict['assessment']}")
    if "plan" in soap_dict:
        formatted.append(f"P: {soap_dict['plan']}")
    return "\n\n".join(formatted)

# If we successfully parsed JSON, display it in the traditional SOAP format
if 'parsed_json' in locals():
    print("\nFormatted SOAP Summary:")
    print(format_soap_display(parsed_json))

# Compare with ground truth
print("\nGround truth SOAP summary:")
print(dataset['train'][121]['soap'])
# Out:
# Attempting to parse JSON response:
# Successfully parsed JSON:
# {
#   "subjective": "Patient reports feeling short of breath and having a productive cough.",
#   "objective": "CT angiogram shows spiculated nodules in bilateral lower lobes, right hilar lymphadenopathy, and emphysematous changes in lungs; pathology results indicate a moderately differentiated nonkeratinizing squamous cell carcinoma in the left lung nodule and highly atypical large lymphocytes with 95% monoclonal B-cells in the right lymph node.",
#   "assessment": "The patient has a history of COPD, and recent imaging suggests malignancy involving both the lung and lymph nodes. Further evaluation through biopsy and consultation with radiation oncology is needed.",
#   "plan": "Discharged with supplemental oxygen therapy, initiated IV furosemide for peripheral edema, and scheduled for a CT chest with contrast monitoring. Follow-up with radiation oncology for further management."
# }
#
# Validation successful! All required fields are present.
#
# Formatted SOAP Summary:
# S: Patient reports feeling short of breath and having a productive cough.
#
# O: CT angiogram shows spiculated nodules in bilateral lower lobes, right hilar lymphadenopathy, and emphysematous changes in lungs; pathology results indicate a moderately differentiated nonkeratinizing squamous cell carcinoma in the left lung nodule and highly atypical large lymphocytes with 95% monoclonal B-cells in the right lymph node.
#
# A: The patient has a history of COPD, and recent imaging suggests malignancy involving both the lung and lymph nodes. Further evaluation through biopsy and consultation with radiation oncology is needed.
#
# P: Discharged with supplemental oxygen therapy, initiated IV furosemide for peripheral edema, and scheduled for a CT chest with contrast monitoring. Follow-up with radiation oncology for further management.
#
# Ground truth SOAP summary:
# S: The patient, with a history of chronic obstructive pulmonary disease (COPD), presents with shortness of breath and a productive cough. He reports worsening dyspnea and a productive cough eight weeks post initial admission.
# O: Initial CT angiogram revealed spiculated nodules in bilateral lower lobes and right hilar lymphadenopathy. Pathology confirmed a moderately differentiated nonkeratinizing squamous cell carcinoma of the left lung nodule and highly atypical large lymphocytes in the right lymph node, suggestive of large B-cell lymphoma. Recent CT chest with contrast showed a large, centrally necrotic mass measuring 18.1 cm x 8 cm. Vital signs indicate hemodynamic stability with no increased oxygen requirements, but physical exam shows facial swelling, jugular venous distention, diffuse wheezing, bilateral basal crackles, and bilateral pitting pedal edema.
# A: Primary diagnosis of squamous cell carcinoma of the lung with concurrent large B-cell lymphoma. Differential diagnosis includes complications from COPD and potential metastasis or progression of known malignancies. Prognosis is guarded given the advanced nature of malignancies and COPD.
# P: Continued supplemental oxygen therapy at 3 L/min via nasal cannula. Initiated IV furosemide for peripheral edema and prednisone 50 mg daily for acute COPD exacerbation. Referral to radiation oncology for cancer management and planned lymph node excision biopsy to confirm lymphoma diagnosis. Advised follow-up with radiation oncologist and monitoring for symptom progression. Adjustments to the treatment plan will be made based on ongoing assessments and response to therapy.

# %% [markdown]
# # Configure LLaMA-Factory
# We'll set up LLaMA-Factory to recognize our custom datasets.

# %%
dataset_info = {
    "soap_finetune_train": {
        "file_name": f"{data_dir}/datasets/llamafactory-finetune-data/train.json",
        "columns": {
            "prompt": "instruction",
            "query": "input",
            "response": "output",
            "system": "system",
            "history": "history"
        }
    },
    "soap_finetune_val": {
        "file_name": f"{data_dir}/datasets/llamafactory-finetune-data/val.json",
        "columns": {
            "prompt": "instruction",
            "query": "input",
            "response": "output",
            "system": "system",
            "history": "history"
        }
    }
}

# Write the dataset configuration to a JSON file
with open("/content/LLaMA-Factory/data/dataset_info.json", "r") as f:
    existing_info = json.load(f)

# Update with our new entries
existing_info.update(dataset_info)

# Write back the updated configuration
with open("/content/LLaMA-Factory/data/dataset_info.json", "w") as f:
    json.dump(existing_info, f, indent=4)

print("Dataset configuration updated successfully!")
# Out:
# Dataset configuration updated successfully!

# %% [markdown]
# # LLaMA Factory Fine-tuning Configuration
# We'll create a configuration file for LLaMA-Factory that specifies our fine-tuning settings.

# %%
# %%writefile /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml
#
# ### model
# model_name_or_path: Qwen/Qwen2.5-1.5B-Instruct
# trust_remote_code: true
#
# ### method
# stage: sft
# do_train: true
# finetuning_type: lora
# lora_rank: 16
# lora_alpha: 32      # Standard setting (2x rank)
# lora_dropout: 0.05
# lora_target: all
#
# ### dataset
# dataset: soap_finetune_train
# eval_dataset: soap_finetune_val
# template: qwen
# cutoff_len: 2048
# overwrite_cache: true
# preprocessing_num_workers: 4
#
# ### output
# output_dir: /gdrive/MyDrive/qwen-finetune-v2/models/
# logging_steps: 50
# save_steps: 200
# plot_loss: true
#
# ### train
# per_device_train_batch_size: 1  # Minimum batch size for T4
# gradient_accumulation_steps: 16
# learning_rate: 5.0e-5
# num_train_epochs: 1.5
# lr_scheduler_type: cosine
# warmup_ratio: 0.05
# fp16: true
# gradient_checkpointing: true  # Enable gradient checkpointing to save memory
# max_grad_norm: 0.3
# ddp_timeout: 180000000
# bf16: false
#
# ### eval
# per_device_eval_batch_size: 1
# eval_strategy: steps
# eval_steps: 200
# max_new_tokens: 1024
#
# ### reports
# report_to: wandb
# run_name: qwen-finetune-v2
#
# # Hub upload configuration
# push_to_hub: true
# export_hub_model_id: "hazem74/soap-summary-qwen-v2"
# hub_private_repo: true
# hub_strategy: checkpoint
# Out:
# Writing /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml

# %% [markdown]
# # Start Fine-tuning
# Now we'll start the fine-tuning process using LLaMA-Factory.

# %%
# !cd LLaMA-Factory/ && llamafactory-cli train /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml
# Out:
# 2025-05-04 19:26:13.777074: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746386774.057037    3284 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746386774.133554    3284 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 19:26:14.721882: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO 05-04 19:26:27 __init__.py:190] Automatically detected platform cuda.
# [INFO|2025-05-04 19:26:31] llamafactory.hparams.parser:401 >> Process rank: 0, world size: 1, device: cuda:0, distributed training: False, compute dtype: torch.float16
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 29.0MB/s]
# vocab.json: 100% 2.78M/2.78M [00:02<00:00, 1.17MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 1.92MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:01<00:00, 5.45MB/s]
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:38,199 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:38,199 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:38,199 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:38,199 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:38,199 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:38,199 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:38,199 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-05-04 19:26:38,743 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 660/660 [00:00<00:00, 5.16MB/s]
# [INFO|configuration_utils.py:696] 2025-05-04 19:26:39,980 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-04 19:26:39,983 >> Model config Qwen2Config {
#   "_name_or_path": "Qwen/Qwen2.5-1.5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:40,218 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:40,218 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:40,218 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:40,218 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:40,219 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:40,219 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-04 19:26:40,219 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-05-04 19:26:40,612 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|2025-05-04 19:26:40] llamafactory.data.loader:143 >> Loading dataset /gdrive/MyDrive/qwen-finetune-v2/datasets/llamafactory-finetune-data/train.json...
# Setting num_proc from 4 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split:
0.86 μg/L, Beta human chorionic gonadotrophin (β-HCG) is less than 0.5 mIU/mL, and lactate dehydrogenase (LDH) is 241 UI/ml.
# Patient: That's good to hear, I guess.
# Doctor: The scrotal ultrasound demonstrated a suspicious solid well-defined mass within your right epididymis, measuring 21 x 14 mm. The mass appears slightly heterogeneous with a hyperechoic appearance and a smooth contour. The right testis, distinct from the lesion, is smaller in size, measuring 23 x 12 x 15 mm. There is no anomaly detected in the contralateral scrotum.
# Patient: So, what does this mean, doc?
# Doctor: Based on these findings, I recommend a radical right orchiectomy via an inguinal incision to remove the mass and prevent any potential complications.
# Patient: Alright, if that's what's needed.
# *After surgery and examination of the surgical specimen*
# Doctor: Your surgery went well, and the recovery was uneventful. The surgical specimen consisted of the right testis measuring 3.5x2.5x1 cm in size and the spermatic cord measuring 5 cm in length.
# Patient: That's a relief.
# Doctor: Upon sectioning the specimen, we found a single well-circumscribed nodular tissue with multiple foci of hemorrhage. The microscopic examination showed an admixture of mature lobulated adipose tissue and numerous dilated and thickened-walled blood vessels. There were no signs of malignancies such as germ cell atypia or intraepithelial germ cell neoplasm.
# Patient: So, what's the diagnosis?
# Doctor: The diagnosis is paratesticular angiolipoma, which is a benign tumor. Since we have removed the mass, you should be fine now. Just be sure to follow up with us in case of any changes or concerns.
# Patient: Thank you, doctor. I appreciate your help.
#
# # Task:
# Generate a structured SOAP summary from the above medical dialogue.
# The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.
#
# # JSON Schema:
# {"properties": {"subjective": {"description": "Patient's subjective experiences, symptoms, and concerns as reported in the dialogue.", "title": "Subjective", "type": "string"}, "objective": {"description": "Objective medical findings, vital signs, and examination results mentioned in the dialogue.", "title": "Objective", "type": "string"}, "assessment": {"description": "Clinician's assessment and diagnosis of the patient's condition based on the dialogue.", "title": "Assessment", "type": "string"}, "plan": {"description": "Treatment plan, medications, follow-up instructions, and recommendations discussed in the dialogue.", "title": "Plan", "type": "string"}}, "required": ["subjective", "objective", "assessment", "plan"], "title": "SOAPSummary", "type": "object"}
#
# # SOAP Summary:
# ```json<|im_end|>
# <|im_start|>assistant
# {"subjective": "The patient, a male with a history of right orchitis treated with antibiotics two years ago, presents with a recent onset of painless swelling in the right hemiscrotum. He reports no other symptoms.", "objective": "Physical examination revealed a firm right testicular mass with testicular atrophy. The left testis appeared normal. Laboratory tests showed normal Germ Cell Tumour serum markers: Alpha-fetoprotein (AFP) at 0.86 μg/L, Beta human chorionic gonadotrophin (β-HCG) less than 0.5 mIU/mL, and lactate dehydrogenase (LDH) at 241 UI/ml. Scrotal ultrasound identified a 21 x 14 mm suspicious solid, well-defined mass in the right epididymis, with a heterogeneous, hyperechoic appearance and smooth contour. The right testis measured 23 x 12 x 15 mm. Post-surgical examination of the right testis and spermatic cord showed a well-circumscribed nodular tissue with hemorrhage, but no signs of malignancy. Microscopic examination confirmed the presence of mature lobulated adipose tissue and thickened-walled blood vessels.", "assessment": "The primary diagnosis is paratesticular angiolipoma, a benign tumor. The absence of germ cell atypia or intraepithelial germ cell neoplasm rules out malignancy. The patient's history and clinical findings support this diagnosis.", "plan": "The patient underwent a successful radical right orchiectomy to remove the mass. Post-operative recovery was uneventful. The management plan includes routine follow-up to monitor for any new symptoms or changes. The patient is advised to report any concerns immediately. Further intervention is not anticipated unless new symptoms arise."}
# ```<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100,
12503, 268, 71683, 389, 8777, 1899, 220, 16, 23, 624, 36592, 25, 358, 3900, 429, 8609, 624, 42724, 25, 1205, 3278, 3060, 311, 8718, 697, 2971, 15148, 323, 7500, 6380, 438, 5871, 13, 5209, 1795, 705, 448, 601, 311, 5978, 697, 13351, 5780, 38411, 382, 2, 5430, 510, 31115, 264, 32930, 63232, 12126, 504, 279, 3403, 6457, 21276, 624, 785, 12126, 1265, 2924, 17450, 533, 11, 54289, 11, 36257, ...
# inputs:
# <|im_start|>system
# You are a medical professional tasked with creating structured SOAP notes from patient-doctor dialogues.
# Generate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.
# Your summary should be concise yet comprehensive, capturing all relevant medical information.
# Output must be in valid JSON format according to the provided schema.
# Do not include any text outside the JSON structure.<|im_end|>
# <|im_start|>user
# # Patient-Doctor Dialogue:
# Doctor: Hi, I understand you've been experiencing some epistaxis and petechiae for the past 2 days, is that correct?
# Patient: Yeah, that's right.
# Doctor: Did you have any upper respiratory infection symptoms recently?
# Patient: Yes, about 5 days ago, I was feeling some upper respiratory infection symptoms.
# Doctor: Alright, let's see. Your vital signs are stable, but the physical exam shows oral blisters and a petechial rash over your extremities. Your platelet count is 1 × 109/L, and blood smear confirmed profound thrombocytopenia with normal platelet size and no platelet clumping.
# Patient: Hmm, what does that mean?
# Doctor: Thrombocytopenia means you have a low platelet count, which can cause the symptoms you've been experiencing. We also tested for hepatitis C antibody, HIV antibody, H. pylori stool antigen, CMV PCR, and EBV PCR, and all of them came back negative. Your coagulation function and ADAMTS13 activity are normal, but the respiratory viral panel is positive for rhinovirus.
# Patient: Oh, okay.
# Doctor: We performed a bone marrow biopsy, which showed trilineage maturing hematopoiesis with markedly increased megakaryocytes. Bone marrow flow cytometry and cytogenetic analysis were unremarkable. Based on these findings, you've been diagnosed with ITP, possibly triggered by the rhinovirus infection.
# Patient: I see.
# Doctor: After admission, we started you on IV dexamethasone 40 mg daily for 4 days. IVIG 1 g/kg/day was given on hospital days 4 and 5. However, you developed a severe headache on hospital day 5. A head CT followed by a sella MRI demonstrated a small focus of hemorrhage into a pituitary macroadenoma, consistent with pituitary apoplexy.
# Patient: Oh no, that sounds serious.
# Doctor: We started you on intravenous aminocaproic acid to treat the pituitary apoplexy. You received daily platelet transfusion, but there was no response in platelet count. Romiplostim was administered on hospital day 7 and day 14, but your Rh-negative blood type prevented us from using Anti-D.
# Patient: So, what's the next step?
# Doctor: We transitioned dexamethasone to prednisone 1 mg/kg/day and gradually tapered it down. Unfortunately, your platelet count remained at a single-digit level despite all treatments. As a result, you underwent an uncomplicated laparoscopic splenectomy on hospital day 18.
# Patient: I hope that helps.
# Doctor: We'll continue to monitor your condition closely and adjust treatment as necessary. Please follow up with us to ensure your recovery goes smoothly.
#
# # Task:
# Generate a structured SOAP summary from the above medical dialogue.
# The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.
#
# # JSON Schema:
# {"properties": {"subjective": {"description": "Patient's subjective experiences, symptoms, and concerns as reported in the dialogue.", "title": "Subjective", "type": "string"}, "objective": {"description": "Objective medical findings, vital signs, and examination results mentioned in the dialogue.", "title": "Objective", "type": "string"}, "assessment": {"description": "Clinician's assessment and diagnosis of the patient's condition based on the dialogue.", "title": "Assessment", "type": "string"}, "plan": {"description": "Treatment plan, medications, follow-up instructions, and recommendations discussed in the dialogue.", "title": "Plan", "type": "string"}}, "required": ["subjective", "objective", "assessment", "plan"], "title": "SOAPSummary", "type": "object"}
#
# # SOAP Summary:
# ```json<|im_end|>
# <|im_start|>assistant
# {"subjective": "The patient reports experiencing epistaxis and petechiae for the past 2 days. He also had symptoms of an upper respiratory infection about 5 days ago. He is currently admitted to the hospital.", "objective": "Vital signs are stable. Physical examination reveals oral blisters and a petechial rash over extremities. Laboratory findings include a platelet count of 1 × 10^9/L, blood smear showing profound thrombocytopenia with normal platelet size and no clumping. Tests for hepatitis C, HIV, H. pylori, CMV, and EBV were negative. Coagulation function and ADAMTS13 activity are normal. Respiratory viral panel positive for rhinovirus. Bone marrow biopsy indicates trilineage maturing hematopoiesis with increased megakaryocytes, and unremarkable flow cytometry and cytogenetic analysis. Imaging shows a small focus of hemorrhage into a pituitary macroadenoma, indicative of pituitary apoplexy.", "assessment": "The primary diagnosis is Immune Thrombocytopenic Purpura (ITP), likely triggered by a recent rhinovirus infection. The patient also developed pituitary apoplexy, a complication from treatment. Differential diagnoses were ruled out through extensive testing.", "plan": "Treatment initiated with IV dexamethasone 40 mg daily for 4 days and IVIG 1 g/kg/day on hospital days 4 and 5. Following the development of pituitary apoplexy, intravenous aminocaproic acid was started. Daily platelet transfusions were ineffective, and romiplostim was administered on hospital days 7 and 14. Anti-D was not used due to the patient's Rh-negative blood type. Transitioned from dexamethasone to prednisone 1 mg/kg/day with a tapering plan. An uncomplicated laparoscopic splenectomy was performed on hospital day 18 due to persistent low platelet counts. The patient is advised to continue close monitoring and follow-up to ensure recovery and adjust treatment as necessary."}
# ```<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -10 ...
# labels:
# {"subjective": "The patient reports experiencing epistaxis and petechiae for the past 2 days. He also had symptoms of an upper respiratory infection about 5 days ago. He is currently admitted to the hospital.", "objective": "Vital signs are stable. Physical examination reveals oral blisters and a petechial rash over extremities. Laboratory findings include a platelet count of 1 × 10^9/L, blood smear showing profound thrombocytopenia with normal platelet size and no clumping. Tests for hepatitis C, HIV, H. pylori, CMV, and EBV were negative. Coagulation function and ADAMTS13 activity are normal. Respiratory viral panel positive for rhinovirus. Bone marrow biopsy indicates trilineage maturing hematopoiesis with increased megakaryocytes, and unremarkable flow cytometry and cytogenetic analysis. Imaging shows a small focus of hemorrhage into a pituitary macroadenoma, indicative of pituitary apoplexy.", "assessment": "The primary diagnosis is Immune Thrombocytopenic Purpura (ITP), likely triggered by a recent rhinovirus infection. The patient also developed pituitary apoplexy, a complication from treatment. Differential diagnoses were ruled out through extensive testing.", "plan": "Treatment initiated with IV dexamethasone 40 mg daily for 4 days and IVIG 1 g/kg/day on hospital days 4 and 5. Following the development of pituitary apoplexy, intravenous aminocaproic acid was started. Daily platelet transfusions were ineffective, and romiplostim was administered on hospital days 7 and 14. Anti-D was not used due to the patient's Rh-negative blood type. Transitioned from dexamethasone to prednisone 1 mg/kg/day with a tapering plan. An uncomplicated laparoscopic splenectomy was performed on hospital day 18 due to persistent low platelet counts. The patient is advised to continue close monitoring and follow-up to ensure recovery and adjust treatment as necessary."}
# ```<|im_end|>
#
# [INFO|configuration_utils.py:696] 2025-05-04 19:27:39,255 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-04 19:27:39,257 >> Model config Qwen2Config {
#   "_name_or_path": "Qwen/Qwen2.5-1.5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|2025-05-04 19:27:39] llamafactory.model.model_utils.kv_cache:143 >> KV cache is disabled during training.
# model.safetensors: 100% 3.09G/3.09G [00:18<00:00, 167MB/s]
# [INFO|modeling_utils.py:3904] 2025-05-04 19:27:58,718 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/model.safetensors
# [INFO|modeling_utils.py:1582] 2025-05-04 19:27:58,819 >> Instantiating Qwen2ForCausalLM model under default dtype torch.float16.
# [INFO|configuration_utils.py:1140] 2025-05-04 19:27:58,830 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "use_cache": false
# }
#
# [INFO|modeling_utils.py:4888] 2025-05-04 19:28:05,755 >> All model checkpoint weights were used when initializing Qwen2ForCausalLM.
#
# [INFO|modeling_utils.py:4896] 2025-05-04 19:28:05,756 >> All the weights of Qwen2ForCausalLM were initialized from the model checkpoint at Qwen/Qwen2.5-1.5B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2ForCausalLM for predictions without further training.
# generation_config.json: 100% 242/242 [00:00<00:00, 1.45MB/s]
# [INFO|configuration_utils.py:1095] 2025-05-04 19:28:06,376 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/generation_config.json
# [INFO|configuration_utils.py:1140] 2025-05-04 19:28:06,377 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.1,
#   "temperature": 0.7,
#   "top_k": 20,
#   "top_p": 0.8
# }
#
# [INFO|2025-05-04 19:28:06] llamafactory.model.model_utils.checkpointing:143 >> Gradient checkpointing enabled.
# [INFO|2025-05-04 19:28:06] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2025-05-04 19:28:06] llamafactory.model.adapter:143 >> Upcasting trainable params to float32.
# [INFO|2025-05-04 19:28:06] llamafactory.model.adapter:143 >> Fine-tuning method: LoRA
# [INFO|2025-05-04 19:28:06] llamafactory.model.model_utils.misc:143 >> Found linear modules: q_proj,o_proj,down_proj,gate_proj,v_proj,k_proj,up_proj
# [INFO|2025-05-04 19:28:07] llamafactory.model.loader:143 >> trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820
# [INFO|trainer.py:741] 2025-05-04 19:28:07,413 >> Using auto half precision backend
# [INFO|trainer.py:2369] 2025-05-04 19:28:07,929 >> ***** Running training *****
# [INFO|trainer.py:2370] 2025-05-04 19:28:07,929 >>   Num examples = 9,000
# [INFO|trainer.py:2371] 2025-05-04 19:28:07,929 >>   Num Epochs = 2
# [INFO|trainer.py:2372] 2025-05-04 19:28:07,929 >>   Instantaneous batch size per device = 1
# [INFO|trainer.py:2375] 2025-05-04 19:28:07,929 >>   Total train batch size (w. parallel, distributed & accumulation) = 16
# [INFO|trainer.py:2376] 2025-05-04 19:28:07,929 >>   Gradient Accumulation steps = 16
# [INFO|trainer.py:2377] 2025-05-04 19:28:07,929 >>   Total optimization steps = 843
# [INFO|trainer.py:2378] 2025-05-04 19:28:07,933 >>   Number of trainable parameters = 18,464,768
# [INFO|integration_utils.py:817] 2025-05-04 19:28:07,937 >> Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: hazemwalied2003 (hazemwalied2003-cairo-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in /content/LLaMA-Factory/wandb/run-20250504_192808-lnzflbux
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run qwen-finetune-v2
# wandb: ⭐️ View project at https://wandb.ai/hazemwalied2003-cairo-university/llamafactory
# wandb: 🚀 View run at https://wandb.ai/hazemwalied2003-cairo-university/llamafactory/runs/lnzflbux
# {'loss': 0.8177, 'grad_norm': 0.3539939820766449, 'learning_rate': 4.999055507493368e-05, 'epoch': 0.09}
# {'loss': 0.6929, 'grad_norm': 0.38573452830314636, 'learning_rate': 4.937631481782218e-05, 'epoch': 0.18}
# {'loss': 0.651, 'grad_norm': 0.3955491781234741, 'learning_rate': 4.782530645265661e-05, 'epoch': 0.27}
# {'loss': 0.6416, 'grad_norm': 0.48218658566474915, 'learning_rate': 4.5397134361094786e-05, 'epoch': 0.36}
#  24% 200/843 [1:05:58<3:38:33, 20.40s/it][INFO|trainer.py:4226] 2025-05-04 20:34:08,656 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4228] 2025-05-04 20:34:08,656 >>   Num examples = 1000
# [INFO|trainer.py:4231] 2025-05-04 20:34:08,656 >>   Batch size = 1
#
#   0% 0/1000 [00:00<?, ?it/s]
#   0% 2/1000 [00:00<03:30,  4.73it/s]
#   0% 3/1000 [00:00<04:32,  3.66it/s]
#   0% 4/1000 [00:01<05:02,  3.30it/s]
#   0% 5/1000 [00:01<05:28,  3.03it/s]
#   1% 6/1000 [00:01<06:02,  2.74it/s]
#   1% 7/1000 [00:02<06:08,  2.69it/s]
#   1% 8/1000 [00:02<06:08,  2.69it/s]
#   1% 9/1000 [00:03<06:03,  2.72it/s]
#   1% 10/1000 [00:03<06:23,  2.58it/s]
#   1% 11/1000 [00:03<06:20,  2.60it/s]
#   1% 12/1000 [00:04<06:31,  2.52it/s]
#   1% 13/1000 [00:04<05:58,  2.75it/s]
#   1% 14/1000 [00:04<06:05,  2.70it/s]
#   2% 15/1000 [00:05<06:09,  2.66it/s]
#   2% 16/1000 [00:05<06:35,  2.49it/s]
#   2% 17/1000 [00:06<06:29,  2.52it/s]
#   2% 18/1000 [00:06<06:17,  2.60it/s]
#   2% 19/1000 [00:06<06:17,  2.60it/s]
#   2% 20/1000 [00:07<06:16,  2.60it/s]
#   2% 21/1000 [00:07<06:07,  2.67it/s]
#   2% 22/1000 [00:08<06:00,  2.71it/s]
#   2% 23/1000 [00:08<06:09,  2.65it/s]
#   2% 24/1000 [00:08<06:12,  2.62it/s]
#   2% 25/1000 [00:09<06:28,  2.51it/s]
#   3% 26/1000 [00:09<06:11,  2.62it/s]
#   3% 27/1000 [00:09<06:04,  2.67it/s]
#   3% 28/1000 [00:10<05:48,  2.79it/s]
#   3% 29/1000 [00:10<05:57,  2.72it/s]
#   3% 30/1000 [00:11<06:00,  2.69it/s]
#   3% 31/1000 [00:11<06:21,  2.54it/s]
#   3% 32/1000 [00:11<06:20,  2.55it/s]
#   3% 33/1000 [00:12<06:20,  2.54it/s]
#   3% 34/1000 [00:12<06:15,  2.57it/s]
#   4% 35/1000 [00:13<06:15,  2.57it/s]
#   4% 36/1000 [00:13<06:17,  2.55it/s]
#   4% 37/1000 [00:13<06:26,  2.49it/s]
#   4% 38/1000 [00:14<06:17,  2.55it/s]
#   4% 39/1000 [00:14<06:16,  2.55it/s]
#   4% 40/1000 [00:14<05:59,  2.67it/s]
#   4% 41/1000 [00:15<05:39,  2.82it/s]
#   4% 42/1000 [00:15<05:38,  2.83it/s]
#   4% 43/1000 [00:15<05:32,  2.88it/s]
#  96% 962/1000 [05:57<00:14,  2.71it/s]
#  96% 963/1000 [05:58<00:13,  2.69it/s]
#  96% 964/1000 [05:58<00:13,  2.62it/s]
#  96% 965/1000 [05:58<00:12,  2.70it/s]
#  97% 966/1000 [05:59<00:12,  2.69it/s]
#  97% 967/1000 [05:59<00:11,  2.77it/s]
#  97% 968/1000 [05:59<00:11,  2.84it/s]
#  97% 969/1000 [06:00<00:10,  2.86it/s]
#  97% 970/1000 [06:00<00:10,  2.73it/s]
#  97% 971/1000 [06:01<00:10,  2.71it/s]
#  97% 972/1000 [06:01<00:09,  2.81it/s]
#  97% 973/1000 [06:01<00:09,  2.73it/s]
#  97% 974/1000 [06:02<00:09,  2.71it/s]
#  98% 975/1000 [06:02<00:09,  2.72it/s]
#  98% 976/1000 [06:02<00:08,  2.76it/s]
#  98% 977/1000 [06:03<00:08,  2.73it/s]
#  98% 978/1000 [06:03<00:08,  2.64it/s]
#  98% 979/1000 [06:04<00:08,  2.58it/s]
#  98% 980/1000 [06:04<00:07,  2.67it/s]
#  98% 981/1000 [06:04<00:07,  2.68it/s]
#  98% 982/1000 [06:05<00:06,  2.75it/s]
#  98% 983/1000 [06:05<00:06,  2.82it/s]
#  98% 984/1000 [06:05<00:05,  2.69it/s]
#  98% 985/1000 [06:06<00:05,  2.64it/s]
#  99% 986/1000 [06:06<00:05,  2.60it/s]
#  99% 987/1000 [06:07<00:04,  2.75it/s]
#  99% 988/1000 [06:07<00:04,  2.68it/s]
#  99% 989/1000 [06:07<00:04,  2.62it/s]
#  99% 990/1000 [06:08<00:03,  2.52it/s]
#  99% 991/1000 [06:08<00:03,  2.72it/s]
#  99% 992/1000 [06:08<00:02,  2.81it/s]
#  99% 993/1000 [06:09<00:02,  2.72it/s]
#  99% 994/1000 [06:09<00:02,  2.74it/s]
# 100% 995/1000 [06:09<00:01,  2.76it/s]
# 100% 996/1000 [06:10<00:01,  2.76it/s]
# 100% 997/1000 [06:10<00:01,  2.96it/s]
# 100% 998/1000 [06:10<00:00,  2.84it/s]
# 100% 999/1000 [06:11<00:00,  2.78it/s]
#
# {'eval_loss': 0.6130089163780212, 'eval_runtime': 372.1377, 'eval_samples_per_second': 2.687, 'eval_steps_per_second': 2.687, 'epoch': 0.71}
#  47% 400/843 [2:24:36<2:25:22, 19.69s/it]
# 100% 1000/1000 [06:11<00:00,  2.79it/s]
#                                        [INFO|trainer.py:3910] 2025-05-04 21:52:45,950 >> Saving model checkpoint to /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-400
# [INFO|configuration_utils.py:696] 2025-05-04 21:52:46,485 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-04 21:52:46,486 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2491] 2025-05-04 21:52:46,777 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-400/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-04 21:52:46,789 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-400/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2491] 2025-05-04 21:52:48,205 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-04 21:52:48,211 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/special_tokens_map.json
# {'loss': 0.6096, 'grad_norm': 0.617023229598999, 'learning_rate': 2.4312863152853165e-05, 'epoch': 0.8}
# {'loss': 0.6083, 'grad_norm': 0.6179319620132446, 'learning_rate': 1.9450650857765102e-05, 'epoch': 0.89}
#  62% 519/843 [3:03:49<1:46:42, 19.76s/it]

# %% [markdown]
# # LLaMA Factory finetuning Configuration (continue from checkpoint-400)
# If training was interrupted or you want to continue from a checkpoint, you can use this configuration:

# %%
# %%writefile /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml
#
# ### model
# model_name_or_path: Qwen/Qwen2.5-1.5B-Instruct
# trust_remote_code: true
#
# ### method
# stage: sft
# do_train: true
# finetuning_type: lora
# lora_rank: 16
# lora_alpha: 32      # Standard setting (2x rank)
# lora_dropout: 0.05
# lora_target: all
#
# ### checkpoint to resume from
# resume_from_checkpoint: /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-400
#
# ### dataset
# dataset: soap_finetune_train
# eval_dataset: soap_finetune_val
# template: qwen
# cutoff_len: 2048
# overwrite_cache: true
# preprocessing_num_workers: 4
#
# ### output
# output_dir: /gdrive/MyDrive/qwen-finetune-v2/models/
# logging_steps: 50
# save_steps: 200
# plot_loss: true
#
# ### train
# per_device_train_batch_size: 1  # Minimum batch size for T4
# gradient_accumulation_steps: 16
# learning_rate: 5.0e-5
# num_train_epochs: 1.5
# lr_scheduler_type: cosine
# warmup_ratio: 0.05
# fp16: true
# gradient_checkpointing: true  # Enable gradient checkpointing to save memory
# max_grad_norm: 0.3
# ddp_timeout: 180000000
# bf16: false
#
# ### eval
# per_device_eval_batch_size: 1
# eval_strategy: steps
# eval_steps: 200
# max_new_tokens: 1024
#
# ### reports
# report_to: wandb
# run_name: qwen-finetune-v2
#
# # Hub upload configuration
# push_to_hub: true
# export_hub_model_id: "hazem74/soap-summary-qwen-v2"
# hub_private_repo: true
# hub_strategy: checkpoint
# Out:
# Writing /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml

# %%
# !cd LLaMA-Factory/ && llamafactory-cli train /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml
# Out:
# 2025-05-06 09:45:30.123927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746524730.391474    3517 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746524730.461294    3517 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-06 09:45:31.019008: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO 05-06 09:45:41 __init__.py:190] Automatically detected platform cuda.
# [INFO|2025-05-06 09:45:44] llamafactory.hparams.parser:401 >> Process rank: 0, world size: 1, device: cuda:0, distributed training: False, compute dtype: torch.float16
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 29.5MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 4.19MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 20.7MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 15.0MB/s]
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:48,924 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:48,924 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:48,924 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:48,924 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:48,924 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:48,924 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:48,924 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-05-06 09:45:49,291 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 660/660 [00:00<00:00, 3.87MB/s]
# [INFO|configuration_utils.py:696] 2025-05-06 09:45:50,932 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-06 09:45:50,935 >> Model config Qwen2Config {
#   "_name_or_path": "Qwen/Qwen2.5-1.5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:51,182 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:51,182 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:51,182 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:51,182 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:51,182 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:51,182 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-06 09:45:51,182 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-05-06 09:45:51,534 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|2025-05-06 09:45:51] llamafactory.data.loader:143 >> Loading dataset /gdrive/MyDrive/qwen-finetune-v2/datasets/llamafactory-finetune-data/train.json...
# Setting num_proc from 4 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 9000 examples [00:01, 5919.80 examples/s]
# Converting format of dataset (num_proc=4): 100% 9000/9000 [00:01<00:00, 6943.48 examples/s]
# [INFO|2025-05-06 09:45:55] llamafactory.data.loader:143 >> Loading dataset /gdrive/MyDrive/qwen-finetune-v2/datasets/llamafactory-finetune-data/val.json...
# Setting num_proc from 4 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split:
0.86 μg/L, Beta human chorionic gonadotrophin (β-HCG) is less than 0.5 mIU/mL, and lactate dehydrogenase (LDH) is 241 UI/ml.
# Patient: That's good to hear, I guess.
# Doctor: The scrotal ultrasound demonstrated a suspicious solid well-defined mass within your right epididymis, measuring 21 x 14 mm. The mass appears slightly heterogeneous with a hyperechoic appearance and a smooth contour. The right testis, distinct from the lesion, is smaller in size, measuring 23 x 12 x 15 mm. There is no anomaly detected in the contralateral scrotum.
# Patient: So, what does this mean, doc?
# Doctor: Based on these findings, I recommend a radical right orchiectomy via an inguinal incision to remove the mass and prevent any potential complications.
# Patient: Alright, if that's what's needed.
# *After surgery and examination of the surgical specimen*
# Doctor: Your surgery went well, and the recovery was uneventful. The surgical specimen consisted of the right testis measuring 3.5x2.5x1 cm in size and the spermatic cord measuring 5 cm in length.
# Patient: That's a relief.
# Doctor: Upon sectioning the specimen, we found a single well-circumscribed nodular tissue with multiple foci of hemorrhage. The microscopic examination showed an admixture of mature lobulated adipose tissue and numerous dilated and thickened-walled blood vessels. There were no signs of malignancies such as germ cell atypia or intraepithelial germ cell neoplasm.
# Patient: So, what's the diagnosis?
# Doctor: The diagnosis is paratesticular angiolipoma, which is a benign tumor. Since we have removed the mass, you should be fine now. Just be sure to follow up with us in case of any changes or concerns.
# Patient: Thank you, doctor. I appreciate your help.
#
# # Task:
# Generate a structured SOAP summary from the above medical dialogue.
# The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.
#
# # JSON Schema:
# {"properties": {"subjective": {"description": "Patient's subjective experiences, symptoms, and concerns as reported in the dialogue.", "title": "Subjective", "type": "string"}, "objective": {"description": "Objective medical findings, vital signs, and examination results mentioned in the dialogue.", "title": "Objective", "type": "string"}, "assessment": {"description": "Clinician's assessment and diagnosis of the patient's condition based on the dialogue.", "title": "Assessment", "type": "string"}, "plan": {"description": "Treatment plan, medications, follow-up instructions, and recommendations discussed in the dialogue.", "title": "Plan", "type": "string"}}, "required": ["subjective", "objective", "assessment", "plan"], "title": "SOAPSummary", "type": "object"}
#
# # SOAP Summary:
# ```json<|im_end|>
# <|im_start|>assistant
# {"subjective": "The patient, a male with a history of right orchitis treated with antibiotics two years ago, presents with a recent onset of painless swelling in the right hemiscrotum. He reports no other symptoms.", "objective": "Physical examination revealed a firm right testicular mass with testicular atrophy. The left testis appeared normal. Laboratory tests showed normal Germ Cell Tumour serum markers: Alpha-fetoprotein (AFP) at 0.86 μg/L, Beta human chorionic gonadotrophin (β-HCG) less than 0.5 mIU/mL, and lactate dehydrogenase (LDH) at 241 UI/ml. Scrotal ultrasound identified a 21 x 14 mm suspicious solid, well-defined mass in the right epididymis, with a heterogeneous, hyperechoic appearance and smooth contour. The right testis measured 23 x 12 x 15 mm. Post-surgical examination of the right testis and spermatic cord showed a well-circumscribed nodular tissue with hemorrhage, but no signs of malignancy. Microscopic examination confirmed the presence of mature lobulated adipose tissue and thickened-walled blood vessels.", "assessment": "The primary diagnosis is paratesticular angiolipoma, a benign tumor. The absence of germ cell atypia or intraepithelial germ cell neoplasm rules out malignancy. The patient's history and clinical findings support this diagnosis.", "plan": "The patient underwent a successful radical right orchiectomy to remove the mass. Post-operative recovery was uneventful. The management plan includes routine follow-up to monitor for any new symptoms or changes. The patient is advised to report any concerns immediately. Further intervention is not anticipated unless new symptoms arise."}
# ```<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100,
are a medical professional tasked with creating structured SOAP notes from patient-doctor dialogues.
# Generate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.
# Your summary should be concise yet comprehensive, capturing all relevant medical information.
# Output must be in valid JSON format according to the provided schema.
# Do not include any text outside the JSON structure.<|im_end|>
# <|im_start|>user
# # Patient-Doctor Dialogue:
# Doctor: Hi, I understand you've been experiencing some epistaxis and petechiae for the past 2 days, is that correct?
# Patient: Yeah, that's right.
# Doctor: Did you have any upper respiratory infection symptoms recently?
# Patient: Yes, about 5 days ago, I was feeling some upper respiratory infection symptoms.
# Doctor: Alright, let's see. Your vital signs are stable, but the physical exam shows oral blisters and a petechial rash over your extremities. Your platelet count is 1 × 109/L, and blood smear confirmed profound thrombocytopenia with normal platelet size and no platelet clumping.
# Patient: Hmm, what does that mean?
# Doctor: Thrombocytopenia means you have a low platelet count, which can cause the symptoms you've been experiencing. We also tested for hepatitis C antibody, HIV antibody, H. pylori stool antigen, CMV PCR, and EBV PCR, and all of them came back negative. Your coagulation function and ADAMTS13 activity are normal, but the respiratory viral panel is positive for rhinovirus.
# Patient: Oh, okay.
# Doctor: We performed a bone marrow biopsy, which showed trilineage maturing hematopoiesis with markedly increased megakaryocytes. Bone marrow flow cytometry and cytogenetic analysis were unremarkable. Based on these findings, you've been diagnosed with ITP, possibly triggered by the rhinovirus infection.
# Patient: I see.
# Doctor: After admission, we started you on IV dexamethasone 40 mg daily for 4 days. IVIG 1 g/kg/day was given on hospital days 4 and 5. However, you developed a severe headache on hospital day 5. A head CT followed by a sella MRI demonstrated a small focus of hemorrhage into a pituitary macroadenoma, consistent with pituitary apoplexy.
# Patient: Oh no, that sounds serious.
# Doctor: We started you on intravenous aminocaproic acid to treat the pituitary apoplexy. You received daily platelet transfusion, but there was no response in platelet count. Romiplostim was administered on hospital day 7 and day 14, but your Rh-negative blood type prevented us from using Anti-D.
# Patient: So, what's the next step?
# Doctor: We transitioned dexamethasone to prednisone 1 mg/kg/day and gradually tapered it down. Unfortunately, your platelet count remained at a single-digit level despite all treatments. As a result, you underwent an uncomplicated laparoscopic splenectomy on hospital day 18.
# Patient: I hope that helps.
# Doctor: We'll continue to monitor your condition closely and adjust treatment as necessary. Please follow up with us to ensure your recovery goes smoothly.
#
# # Task:
# Generate a structured SOAP summary from the above medical dialogue.
# The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.
#
# # JSON Schema:
# {"properties": {"subjective": {"description": "Patient's subjective experiences, symptoms, and concerns as reported in the dialogue.", "title": "Subjective", "type": "string"}, "objective": {"description": "Objective medical findings, vital signs, and examination results mentioned in the dialogue.", "title": "Objective", "type": "string"}, "assessment": {"description": "Clinician's assessment and diagnosis of the patient's condition based on the dialogue.", "title": "Assessment", "type": "string"}, "plan": {"description": "Treatment plan, medications, follow-up instructions, and recommendations discussed in the dialogue.", "title": "Plan", "type": "string"}}, "required": ["subjective", "objective", "assessment", "plan"], "title": "SOAPSummary", "type": "object"}
#
# # SOAP Summary:
# ```json<|im_end|>
# <|im_start|>assistant
# {"subjective": "The patient reports experiencing epistaxis and petechiae for the past 2 days. He also had symptoms of an upper respiratory infection about 5 days ago. He is currently admitted to the hospital.", "objective": "Vital signs are stable. Physical examination reveals oral blisters and a petechial rash over extremities. Laboratory findings include a platelet count of 1 × 10^9/L, blood smear showing profound thrombocytopenia with normal platelet size and no clumping. Tests for hepatitis C, HIV, H. pylori, CMV, and EBV were negative. Coagulation function and ADAMTS13 activity are normal. Respiratory viral panel positive for rhinovirus. Bone marrow biopsy indicates trilineage maturing hematopoiesis with increased megakaryocytes, and unremarkable flow cytometry and cytogenetic analysis. Imaging shows a small focus of hemorrhage into a pituitary macroadenoma, indicative of pituitary apoplexy.", "assessment": "The primary diagnosis is Immune Thrombocytopenic Purpura (ITP), likely triggered by a recent rhinovirus infection. The patient also developed pituitary apoplexy, a complication from treatment. Differential diagnoses were ruled out through extensive testing.", "plan": "Treatment initiated with IV dexamethasone 40 mg daily for 4 days and IVIG 1 g/kg/day on hospital days 4 and 5. Following the development of pituitary apoplexy, intravenous aminocaproic acid was started. Daily platelet transfusions were ineffective, and romiplostim was administered on hospital days 7 and 14. Anti-D was not used due to the patient's Rh-negative blood type. Transitioned from dexamethasone to prednisone 1 mg/kg/day with a tapering plan. An uncomplicated laparoscopic splenectomy was performed on hospital day 18 due to persistent low platelet counts. The patient is advised to continue close monitoring and follow-up to ensure recovery and adjust treatment as necessary."}
# ```<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -10 ...
# labels:
# {"subjective": "The patient reports experiencing epistaxis and petechiae for the past 2 days. He also had symptoms of an upper respiratory infection about 5 days ago. He is currently admitted to the hospital.", "objective": "Vital signs are stable. Physical examination reveals oral blisters and a petechial rash over extremities. Laboratory findings include a platelet count of 1 × 10^9/L, blood smear showing profound thrombocytopenia with normal platelet size and no clumping. Tests for hepatitis C, HIV, H. pylori, CMV, and EBV were negative. Coagulation function and ADAMTS13 activity are normal. Respiratory viral panel positive for rhinovirus. Bone marrow biopsy indicates trilineage maturing hematopoiesis with increased megakaryocytes, and unremarkable flow cytometry and cytogenetic analysis. Imaging shows a small focus of hemorrhage into a pituitary macroadenoma, indicative of pituitary apoplexy.", "assessment": "The primary diagnosis is Immune Thrombocytopenic Purpura (ITP), likely triggered by a recent rhinovirus infection. The patient also developed pituitary apoplexy, a complication from treatment. Differential diagnoses were ruled out through extensive testing.", "plan": "Treatment initiated with IV dexamethasone 40 mg daily for 4 days and IVIG 1 g/kg/day on hospital days 4 and 5. Following the development of pituitary apoplexy, intravenous aminocaproic acid was started. Daily platelet transfusions were ineffective, and romiplostim was administered on hospital days 7 and 14. Anti-D was not used due to the patient's Rh-negative blood type. Transitioned from dexamethasone to prednisone 1 mg/kg/day with a tapering plan. An uncomplicated laparoscopic splenectomy was performed on hospital day 18 due to persistent low platelet counts. The patient is advised to continue close monitoring and follow-up to ensure recovery and adjust treatment as necessary."}
# ```<|im_end|>
#
# [INFO|configuration_utils.py:696] 2025-05-06 09:46:46,874 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-06 09:46:46,875 >> Model config Qwen2Config {
#   "_name_or_path": "Qwen/Qwen2.5-1.5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|2025-05-06 09:46:46] llamafactory.model.model_utils.kv_cache:143 >> KV cache is disabled during training.
# model.safetensors: 100% 3.09G/3.09G [00:14<00:00, 208MB/s]
# [INFO|modeling_utils.py:3904] 2025-05-06 09:47:02,868 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/model.safetensors
# [INFO|modeling_utils.py:1582] 2025-05-06 09:47:02,954 >> Instantiating Qwen2ForCausalLM model under default dtype torch.float16.
# [INFO|configuration_utils.py:1140] 2025-05-06 09:47:02,958 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "use_cache": false
# }
#
# [INFO|modeling_utils.py:4888] 2025-05-06 09:47:07,560 >> All model checkpoint weights were used when initializing Qwen2ForCausalLM.
#
# [INFO|modeling_utils.py:4896] 2025-05-06 09:47:07,560 >> All the weights of Qwen2ForCausalLM were initialized from the model checkpoint at Qwen/Qwen2.5-1.5B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2ForCausalLM for predictions without further training.
# generation_config.json: 100% 242/242 [00:00<00:00, 1.60MB/s]
# [INFO|configuration_utils.py:1095] 2025-05-06 09:47:08,130 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/generation_config.json
# [INFO|configuration_utils.py:1140] 2025-05-06 09:47:08,131 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.1,
#   "temperature": 0.7,
#   "top_k": 20,
#   "top_p": 0.8
# }
#
# [INFO|2025-05-06 09:47:08] llamafactory.model.model_utils.checkpointing:143 >> Gradient checkpointing enabled.
# [INFO|2025-05-06 09:47:08] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2025-05-06 09:47:08] llamafactory.model.adapter:143 >> Upcasting trainable params to float32.
# [INFO|2025-05-06 09:47:08] llamafactory.model.adapter:143 >> Fine-tuning method: LoRA
# [INFO|2025-05-06 09:47:08] llamafactory.model.model_utils.misc:143 >> Found linear modules: down_proj,o_proj,q_proj,k_proj,v_proj,gate_proj,up_proj
# [INFO|2025-05-06 09:47:08] llamafactory.model.loader:143 >> trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820
# [INFO|trainer.py:741] 2025-05-06 09:47:08,976 >> Using auto half precision backend
# [INFO|trainer.py:2775] 2025-05-06 09:47:10,513 >> Loading model from /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-400.
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py:3441: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(os.path.join(checkpoint, OPTIMIZER_NAME), map_location=map_location)
# [INFO|trainer.py:2369] 2025-05-06 09:47:21,703 >> ***** Running training *****
# [INFO|trainer.py:2370] 2025-05-06 09:47:21,703 >>   Num examples = 9,000
# [INFO|trainer.py:2371] 2025-05-06 09:47:21,703 >>   Num Epochs = 2
# [INFO|trainer.py:2372] 2025-05-06 09:47:21,703 >>   Instantaneous batch size per device = 1
# [INFO|trainer.py:2375] 2025-05-06 09:47:21,703 >>   Total train batch size (w. parallel, distributed & accumulation) = 16
# [INFO|trainer.py:2376] 2025-05-06 09:47:21,703 >>   Gradient Accumulation steps = 16
# [INFO|trainer.py:2377] 2025-05-06 09:47:21,703 >>   Total optimization steps = 843
# [INFO|trainer.py:2378] 2025-05-06 09:47:21,710 >>   Number of trainable parameters = 18,464,768
# [INFO|trainer.py:2400] 2025-05-06 09:47:21,714 >>   Continuing training from checkpoint, will skip to saved global_step
# [INFO|trainer.py:2401] 2025-05-06 09:47:21,714 >>   Continuing training from epoch 0
# [INFO|trainer.py:2402] 2025-05-06 09:47:21,714 >>   Continuing training from global step 400
# [INFO|trainer.py:2404] 2025-05-06 09:47:21,714 >>   Will skip the first 0 epochs then the first 6400 batches in the first epoch.
# [INFO|integration_utils.py:817] 2025-05-06 09:47:21,721 >> Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: hazemwalied2003 (hazemwalied2003-cairo-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in /content/LLaMA-Factory/wandb/run-20250506_094722-ano5062d
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run qwen-finetune-v2
# wandb: ⭐️ View project at https://wandb.ai/hazemwalied2003-cairo-university/llamafactory
# wandb: 🚀 View run at https://wandb.ai/hazemwalied2003-cairo-university/llamafactory/runs/ano5062d
#   0% 0/843 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/transformers/trainer.py:3105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_rng_state = torch.load(rng_file)
# {'loss': 0.6096, 'grad_norm': 0.6172184348106384, 'learning_rate': 2.4312863152853165e-05, 'epoch': 0.8}
# {'loss': 0.6083, 'grad_norm': 0.6180198788642883, 'learning_rate': 1.9450650857765102e-05, 'epoch': 0.89}
# {'loss': 0.5901, 'grad_norm': 0.5852562189102173, 'learning_rate': 1.4801696938102272e-05, 'epoch': 0.98}
# {'loss': 0.5984, 'grad_norm': 0.7027085423469543, 'learning_rate': 1.0544658085833919e-05, 'epoch': 1.07}
#  71% 600/843 [1:03:05<1:14:35, 18.42s/it][INFO|trainer.py:4226] 2025-05-06 10:50:29,266 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4228] 2025-05-06 10:50:29,267 >>   Num examples = 1000
# [INFO|trainer.py:4231] 2025-05-06 10:50:29,267 >>   Batch size = 1
#
#   0% 0/1000 [00:00<?, ?it/s]
#   0% 2/1000 [00:00<03:15,  5.10it/s]
#   0% 3/1000 [00:00<04:18,  3.86it/s]
#   0% 4/1000 [00:01<04:45,  3.49it/s]
#   0% 5/1000 [00:01<05:05,  3.25it/s]
#   1% 6/1000 [00:01<05:39,  2.93it/s]
#   1% 7/1000 [00:02<05:47,  2.86it/s]
#   1% 8/1000 [00:02<05:43,  2.88it/s]
#   1% 9/1000 [00:02<05:41,  2.90it/s]
#   1% 10/1000 [00:03<05:59,  2.75it/s]
#   1% 11/1000 [00:03<05:57,  2.76it/s]
#   1% 12/1000 [00:04<06:06,  2.69it/s]
#   1% 13/1000 [00:04<05:36,  2.93it/s]
#   1% 14/1000 [00:04<05:43,  2.87it/s]
#   2% 15/1000 [00:05<05:48,  2.82it/s]
#   2% 16/1000 [00:05<06:13,  2.64it/s]
#   2% 17/1000 [00:05<06:10,  2.65it/s]
#   2% 18/1000 [00:06<05:56,  2.75it/s]
#   2% 19/1000 [00:06<05:55,  2.76it/s]
#   2% 20/1000 [00:06<05:53,  2.77it/s]
#   2% 21/1000 [00:07<05:46,  2.83it/s]
#   2% 22/1000 [00:07<05:39,  2.88it/s]
#   2% 23/1000 [00:07<05:46,  2.82it/s]
#   2% 24/1000 [00:08<05:50,  2.79it/s]
#   2% 25/1000 [00:08<06:04,  2.68it/s]
#   3% 26/1000 [00:09<05:51,  2.77it/s]
#   3% 27/1000 [00:09<05:41,  2.85it/s]
#   3% 28/1000 [00:09<05:26,  2.98it/s]
#   3% 29/1000 [00:10<05:35,  2.89it/s]
#   3% 30/1000 [00:10<05:39,  2.85it/s]
#   3% 31/1000 [00:10<05:58,  2.71it/s]
#   3% 32/1000 [00:11<05:57,  2.71it/s]
#   3% 33/1000 [00:11<05:57,  2.71it/s]
#   3% 34/1000 [00:11<05:50,  2.75it/s]
#   4% 35/1000 [00:12<05:54,  2.72it/s]
#   4% 36/1000 [00:12<05:54,  2.72it/s]
#  96% 965/1000 [05:37<00:12,  2.84it/s]
#  97% 966/1000 [05:37<00:11,  2.86it/s]
#  97% 967/1000 [05:38<00:11,  2.95it/s]
#  97% 968/1000 [05:38<00:10,  3.03it/s]
#  97% 969/1000 [05:38<00:10,  3.03it/s]
#  97% 970/1000 [05:39<00:10,  2.90it/s]
#  97% 971/1000 [05:39<00:10,  2.85it/s]
#  97% 972/1000 [05:39<00:09,  2.97it/s]
#  97% 973/1000 [05:40<00:09,  2.87it/s]
#  97% 974/1000 [05:40<00:09,  2.85it/s]
#  98% 975/1000 [05:41<00:08,  2.88it/s]
#  98% 976/1000 [05:41<00:08,  2.91it/s]
#  98% 977/1000 [05:41<00:08,  2.87it/s]
#  98% 978/1000 [05:42<00:07,  2.79it/s]
#  98% 979/1000 [05:42<00:07,  2.72it/s]
#  98% 980/1000 [05:42<00:07,  2.83it/s]
#  98% 981/1000 [05:43<00:06,  2.86it/s]
#  98% 982/1000 [05:43<00:06,  2.91it/s]
#  98% 983/1000 [05:43<00:05,  2.99it/s]
#  98% 984/1000 [05:44<00:05,  2.89it/s]
#  98% 985/1000 [05:44<00:05,  2.81it/s]
#  99% 986/1000 [05:44<00:05,  2.76it/s]
#  99% 987/1000 [05:45<00:04,  2.94it/s]
#  99% 988/1000 [05:45<00:04,  2.85it/s]
#  99% 989/1000 [05:45<00:03,  2.78it/s]
#  99% 990/1000 [05:46<00:03,  2.68it/s]
#  99% 991/1000 [05:46<00:03,  2.88it/s]
#  99% 992/1000 [05:46<00:02,  2.99it/s]
#  99% 993/1000 [05:47<00:02,  2.88it/s]
#  99% 994/1000 [05:47<00:02,  2.91it/s]
# 100% 995/1000 [05:47<00:01,  2.94it/s]
# 100% 996/1000 [05:48<00:01,  2.92it/s]
# 100% 997/1000 [05:48<00:00,  3.12it/s]
# 100% 998/1000 [05:48<00:00,  2.99it/s]
# 100% 999/1000 [05:49<00:00,  2.93it/s]
#
# {'eval_loss': 0.600631594657898, 'eval_runtime': 350.0565, 'eval_samples_per_second': 2.857, 'eval_steps_per_second': 2.857, 'epoch': 1.07}
#  71% 600/843 [1:08:55<1:14:35, 18.42s/it]
# 100% 1000/1000 [05:49<00:00,  2.94it/s]
#                                        [INFO|trainer.py:3910] 2025-05-06 10:56:19,332 >> Saving model checkpoint to /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-600
# [INFO|configuration_utils.py:696] 2025-05-06 10:56:19,891 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-06 10:56:19,892 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2491] 2025-05-06 10:56:20,232 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-600/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-06 10:56:20,240 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-600/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2491] 2025-05-06 10:56:31,317 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-06 10:56:31,910 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/special_tokens_map.json
# {'loss': 0.5705, 'grad_norm': 0.6330472826957703, 'learning_rate': 6.84312991667784e-06, 'epoch': 1.16}
#  79% 665/843 [1:29:53<57:14, 19.30s/it]

# %% [markdown]
# # LLaMA Factory finetuning Configuration (continue from checkpoint-600)

# %%
# %%writefile /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml
#
# ### model
# model_name_or_path: Qwen/Qwen2.5-1.5B-Instruct
# trust_remote_code: true
#
# ### method
# stage: sft
# do_train: true
# finetuning_type: lora
# lora_rank: 16
# lora_alpha: 32      # Standard setting (2x rank)
# lora_dropout: 0.05
# lora_target: all
#
# ### checkpoint to resume from
# resume_from_checkpoint: /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-600
#
# ### dataset
# dataset: soap_finetune_train
# eval_dataset: soap_finetune_val
# template: qwen
# cutoff_len: 2048
# overwrite_cache: true
# preprocessing_num_workers: 4
#
# ### output
# output_dir: /gdrive/MyDrive/qwen-finetune-v2/models/
# logging_steps: 50
# save_steps: 200
# plot_loss: true
#
# ### train
# per_device_train_batch_size: 1  # Minimum batch size for T4
# gradient_accumulation_steps: 16
# learning_rate: 5.0e-5
# num_train_epochs: 1.5
# lr_scheduler_type: cosine
# warmup_ratio: 0.05
# fp16: true
# gradient_checkpointing: true
# max_grad_norm: 0.3
# ddp_timeout: 180000000
# bf16: false
#
# ### eval
# per_device_eval_batch_size: 1
# eval_strategy: steps
# eval_steps: 200
# max_new_tokens: 1024
#
# ### reports
# report_to: wandb
# run_name: qwen-finetune-v2
#
# # Hub upload configuration
# push_to_hub: true
# export_hub_model_id: "hazem74/soap-summary-qwen-v2"
# hub_private_repo: true
# hub_strategy: checkpoint
# Out:
# Writing /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml

# %%
# !cd LLaMA-Factory/ && llamafactory-cli train /content/LLaMA-Factory/examples/train_lora/soap_finetune.yaml
# Out:
# 2025-05-07 12:35:51.097087: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746621351.320727    6622 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746621351.381776    6622 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-07 12:35:51.857540: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO|2025-05-07 12:36:03] llamafactory.hparams.parser:401 >> Process rank: 0, world size: 1, device: cuda:0, distributed training: False, compute dtype: torch.float16
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 30.0MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 29.8MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 5.75MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 12.2MB/s]
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:05,462 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:05,462 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:05,462 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:05,462 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:05,462 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:05,462 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:05,462 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-05-07 12:36:05,820 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 660/660 [00:00<00:00, 5.78MB/s]
# [INFO|configuration_utils.py:696] 2025-05-07 12:36:06,717 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-07 12:36:06,719 >> Model config Qwen2Config {
#   "_name_or_path": "Qwen/Qwen2.5-1.5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:06,821 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/vocab.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:06,821 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/merges.txt
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:06,821 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:06,821 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:06,821 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:06,821 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2034] 2025-05-07 12:36:06,821 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2304] 2025-05-07 12:36:07,187 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|2025-05-07 12:36:07] llamafactory.data.loader:143 >> Loading dataset /gdrive/MyDrive/qwen-finetune-v2/datasets/llamafactory-finetune-data/train.json...
# Setting num_proc from 4 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 9000 examples [00:01, 5876.35 examples/s]
# Converting format of dataset (num_proc=4): 100% 9000/9000 [00:02<00:00, 4465.34 examples/s]
# [INFO|2025-05-07 12:36:11] llamafactory.data.loader:143 >> Loading dataset /gdrive/MyDrive/qwen-finetune-v2/datasets/llamafactory-finetune-data/val.json...
# Setting num_proc from 4 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 1000 examples [00:00, 4390.39 examples/s]
# Converting format of dataset (num_proc=4): 100% 1000/1000 [00:00<00:00, 2123.91 examples/s]
# Running tokenizer on dataset (num_proc=4): 100% 9000/9000 [00:41<00:00, 217.29 examples/s]
# training example:
# input_ids:
# [151644, 8948, 198, 2610, 525, 264,
 6749, 84, 977, 3625, 1816, 311, 4057, 279, 3072, 323, 5358, 894, 4650, 35405, 624, 36592, 25, 97593, 11, 421, 429, 594, 1128, 594, 4362, 624, 9, 6025, 14829, 323, 23568, 315, 279, 33833, 57084, 5618, 42724, 25, 4615, 14829, 3937, 1632, 11, 323, 279, 13351, 572, 650, 3087, 1262, 13, 576, 33833, 57084, 43560, 315, 279, 1290, 1273, 285, 28990, 220, 18, 13, 20, 87, 17, 13, 20, 87, 16, 9961, 304, 1379, 323, 279, 39599, 774, 22324, 28990, 220, 20, 9961, 304, 3084, 624, 36592, 25, 2938, 594, 264, 15957, 624, 42724, 25, 29438, 3772, 287, 279, 57084, 11, 582, 1730, 264, 3175, 1632, 1786, 2437, 6237, 17433, 16004, 1276, 19847, 448, 5248, 282, 2119, 315, 70317, 424, 13, 576, 88990, 23568, 8542, 458, 14591, 12735, 315, 14851, 40153, 7757, 29266, 960, 19847, 323, 12114, 18840, 657, 323, 12045, 6758, 2630, 4736, 6543, 29980, 13, 2619, 1033, 902, 11929, 315, 59227, 31637, 1741, 438, 81886, 2779, 518, 1082, 685, 476, 49838, 747, 410, 58444, 81886, 2779, 834, 55078, 10530, 624, 36592, 25, 2055, 11, 1128, 594, 279, 22982, 5267, 42724, 25, 576, 22982, 374, 1346, 13893, 23632, 6454, 24903, 573, 7786, 11, 892, 374, 264, 64209, 35154, 13, 8704, 582, 614, 6963, 279, 3072, 11, 498, 1265, 387, 6915, 1431, 13, 4599, 387, 2704, 311, 1795, 705, 448, 601, 304, 1142, 315, 894, 4344, 476, 10520, 624, 36592, 25, 9731, 498, 11, 10668, 13, 358, 15401, 697, 1492, 382, 2, 5430, 510, 31115, 264, 32930, 63232, 12126, 504, 279, 3403, 6457, 21276, 624, 785, 12126, 1265, 2924, 17450,  ...
# inputs:
# <|im_start|>system
# You are a medical professional tasked with creating structured SOAP notes from patient-doctor dialogues.
# Generate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.
# Your summary should be concise yet comprehensive, capturing all relevant medical information.
# Output must be in valid JSON format according to the provided schema.
# Do not include any text outside the JSON structure.<|im_end|>
# <|im_start|>user
# # Patient-Doctor Dialogue:
# Doctor: Hello, I understand that you have a history of right orchitis that was treated with antibiotics two years ago. What brings you in today?
# Patient: Hi, doctor. I've noticed a painless swelling in my right hemiscrotum recently. I don't have any other symptoms, but it's concerning me.
# Doctor: I see. Let me perform a local examination to check for any abnormalities. *After examining* I can feel a firm right testicular mass with atrophy of the whole testis. Your left testis in the scrotum seems normal in size with no suspicious mass. We'll need to do some laboratory tests and an ultrasound to get more information.
# Patient: Okay, I'll do the tests.
# *After tests*
# Doctor: Your laboratory findings, including Germ Cell Tumour serum markers, are within the normal range. Your Alpha-fetoprotein (AFP) is 0.86 μg/L, Beta human chorionic gonadotrophin (β-HCG) is less than 0.5 mIU/mL, and lactate dehydrogenase (LDH) is 241 UI/ml.
# Patient: That's good to hear, I guess.
# Doctor: The scrotal ultrasound demonstrated a suspicious solid well-defined mass within your right epididymis, measuring 21 x 14 mm. The mass appears slightly heterogeneous with a hyperechoic appearance and a smooth contour. The right testis, distinct from the lesion, is smaller in size, measuring 23 x 12 x 15 mm. There is no anomaly detected in the contralateral scrotum.
# Patient: So, what does this mean, doc?
# Doctor: Based on these findings, I recommend a radical right orchiectomy via an inguinal incision to remove the mass and prevent any potential complications.
# Patient: Alright, if that's what's needed.
# *After surgery and examination of the surgical specimen*
# Doctor: Your surgery went well, and the recovery was uneventful. The surgical specimen consisted of the right testis measuring 3.5x2.5x1 cm in size and the spermatic cord measuring 5 cm in length.
# Patient: That's a relief.
# Doctor: Upon sectioning the specimen, we found a single well-circumscribed nodular tissue with multiple foci of hemorrhage. The microscopic examination showed an admixture of mature lobulated adipose tissue and numerous dilated and thickened-walled blood vessels. There were no signs of malignancies such as germ cell atypia or intraepithelial germ cell neoplasm.
# Patient: So, what's the diagnosis?
# Doctor: The diagnosis is paratesticular angiolipoma, which is a benign tumor. Since we have removed the mass, you should be fine now. Just be sure to follow up with us in case of any changes or concerns.
# Patient: Thank you, doctor. I appreciate your help.
#
# # Task:
# Generate a structured SOAP summary from the above medical dialogue.
# The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.
#
# # JSON Schema:
# {"properties": {"subjective": {"description": "Patient's subjective experiences, symptoms, and concerns as reported in the dialogue.", "title": "Subjective", "type": "string"}, "objective": {"description": "Objective medical findings, vital signs, and examination results mentioned in the dialogue.", "title": "Objective", "type": "string"}, "assessment": {"description": "Clinician's assessment and diagnosis of the patient's condition based on the dialogue.", "title": "Assessment", "type": "string"}, "plan": {"description": "Treatment plan, medications, follow-up instructions, and recommendations discussed in the dialogue.", "title": "Plan", "type": "string"}}, "required": ["subjective", "objective", "assessment", "plan"], "title": "SOAPSummary", "type": "object"}
#
# # SOAP Summary:
# ```json<|im_end|>
# <|im_start|>assistant
# {"subjective": "The patient, a male with a history of right orchitis treated with antibiotics two years ago, presents with a recent onset of painless swelling in the right hemiscrotum. He reports no other symptoms.", "objective": "Physical examination revealed a firm right testicular mass with testicular atrophy. The left testis appeared normal. Laboratory tests showed normal Germ Cell Tumour serum markers: Alpha-fetoprotein (AFP) at 0.86 μg/L, Beta human chorionic gonadotrophin (β-HCG) less than 0.5 mIU/mL, and lactate dehydrogenase (LDH) at 241 UI/ml. Scrotal ultrasound identified a 21 x 14 mm suspicious solid, well-defined mass in the right epididymis, with a heterogeneous, hyperechoic appearance and smooth contour. The right testis measured 23 x 12 x 15 mm. Post-surgical examination of the right testis and spermatic cord showed a well-circumscribed nodular tissue with hemorrhage, but no signs of malignancy. Microscopic examination confirmed the presence of mature lobulated adipose tissue and thickened-walled blood vessels.", "assessment": "The primary diagnosis is paratesticular angiolipoma, a benign tumor. The absence of germ cell atypia or intraepithelial germ cell neoplasm rules out malignancy. The patient's history and clinical findings support this diagnosis.", "plan": "The patient underwent a successful radical right orchiectomy to remove the mass. Post-operative recovery was uneventful. The management plan includes routine follow-up to monitor for any new symptoms or changes. The patient is advised to report any concerns immediately. Further intervention is not anticipated unless new symptoms arise."}
# ```<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100,
generate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.
# Your summary should be concise yet comprehensive, capturing all relevant medical information.
# Output must be in valid JSON format according to the provided schema.
# Do not include any text outside the JSON structure.<|im_end|>
# <|im_start|>user
# # Patient-Doctor Dialogue:
# Doctor: Hi, I understand you've been experiencing some epistaxis and petechiae for the past 2 days, is that correct?
# Patient: Yeah, that's right.
# Doctor: Did you have any upper respiratory infection symptoms recently?
# Patient: Yes, about 5 days ago, I was feeling some upper respiratory infection symptoms.
# Doctor: Alright, let's see. Your vital signs are stable, but the physical exam shows oral blisters and a petechial rash over your extremities. Your platelet count is 1 × 109/L, and blood smear confirmed profound thrombocytopenia with normal platelet size and no platelet clumping.
# Patient: Hmm, what does that mean?
# Doctor: Thrombocytopenia means you have a low platelet count, which can cause the symptoms you've been experiencing. We also tested for hepatitis C antibody, HIV antibody, H. pylori stool antigen, CMV PCR, and EBV PCR, and all of them came back negative. Your coagulation function and ADAMTS13 activity are normal, but the respiratory viral panel is positive for rhinovirus.
# Patient: Oh, okay.
# Doctor: We performed a bone marrow biopsy, which showed trilineage maturing hematopoiesis with markedly increased megakaryocytes. Bone marrow flow cytometry and cytogenetic analysis were unremarkable. Based on these findings, you've been diagnosed with ITP, possibly triggered by the rhinovirus infection.
# Patient: I see.
# Doctor: After admission, we started you on IV dexamethasone 40 mg daily for 4 days. IVIG 1 g/kg/day was given on hospital days 4 and 5. However, you developed a severe headache on hospital day 5. A head CT followed by a sella MRI demonstrated a small focus of hemorrhage into a pituitary macroadenoma, consistent with pituitary apoplexy.
# Patient: Oh no, that sounds serious.
# Doctor: We started you on intravenous aminocaproic acid to treat the pituitary apoplexy. You received daily platelet transfusion, but there was no response in platelet count. Romiplostim was administered on hospital day 7 and day 14, but your Rh-negative blood type prevented us from using Anti-D.
# Patient: So, what's the next step?
# Doctor: We transitioned dexamethasone to prednisone 1 mg/kg/day and gradually tapered it down. Unfortunately, your platelet count remained at a single-digit level despite all treatments. As a result, you underwent an uncomplicated laparoscopic splenectomy on hospital day 18.
# Patient: I hope that helps.
# Doctor: We'll continue to monitor your condition closely and adjust treatment as necessary. Please follow up with us to ensure your recovery goes smoothly.
#
# # Task:
# Generate a structured SOAP summary from the above medical dialogue.
# The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.
#
# # JSON Schema:
# {"properties": {"subjective": {"description": "Patient's subjective experiences, symptoms, and concerns as reported in the dialogue.", "title": "Subjective", "type": "string"}, "objective": {"description": "Objective medical findings, vital signs, and examination results mentioned in the dialogue.", "title": "Objective", "type": "string"}, "assessment": {"description": "Clinician's assessment and diagnosis of the patient's condition based on the dialogue.", "title": "Assessment", "type": "string"}, "plan": {"description": "Treatment plan, medications, follow-up instructions, and recommendations discussed in the dialogue.", "title": "Plan", "type": "string"}}, "required": ["subjective", "objective", "assessment", "plan"], "title": "SOAPSummary", "type": "object"}
#
# # SOAP Summary:
# ```json<|im_end|>
# <|im_start|>assistant
# {"subjective": "The patient reports experiencing epistaxis and petechiae for the past 2 days. He also had symptoms of an upper respiratory infection about 5 days ago. He is currently admitted to the hospital.", "objective": "Vital signs are stable. Physical examination reveals oral blisters and a petechial rash over extremities. Laboratory findings include a platelet count of 1 × 10^9/L, blood smear showing profound thrombocytopenia with normal platelet size and no clumping. Tests for hepatitis C, HIV, H. pylori, CMV, and EBV were negative. Coagulation function and ADAMTS13 activity are normal. Respiratory viral panel positive for rhinovirus. Bone marrow biopsy indicates trilineage maturing hematopoiesis with increased megakaryocytes, and unremarkable flow cytometry and cytogenetic analysis. Imaging shows a small focus of hemorrhage into a pituitary macroadenoma, indicative of pituitary apoplexy.", "assessment": "The primary diagnosis is Immune Thrombocytopenic Purpura (ITP), likely triggered by a recent rhinovirus infection. The patient also developed pituitary apoplexy, a complication from treatment. Differential diagnoses were ruled out through extensive testing.", "plan": "Treatment initiated with IV dexamethasone 40 mg daily for 4 days and IVIG 1 g/kg/day on hospital days 4 and 5. Following the development of pituitary apoplexy, intravenous aminocaproic acid was started. Daily platelet transfusions were ineffective, and romiplostim was administered on hospital days 7 and 14. Anti-D was not used due to the patient's Rh-negative blood type. Transitioned from dexamethasone to prednisone 1 mg/kg/day with a tapering plan. An uncomplicated laparoscopic splenectomy was performed on hospital day 18 due to persistent low platelet counts. The patient is advised to continue close monitoring and follow-up to ensure recovery and adjust treatment as necessary."}
# ```<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -10 ...
# labels:
# {"subjective": "The patient reports experiencing epistaxis and petechiae for the past 2 days. He also had symptoms of an upper respiratory infection about 5 days ago. He is currently admitted to the hospital.", "objective": "Vital signs are stable. Physical examination reveals oral blisters and a petechial rash over extremities. Laboratory findings include a platelet count of 1 × 10^9/L, blood smear showing profound thrombocytopenia with normal platelet size and no clumping. Tests for hepatitis C, HIV, H. pylori, CMV, and EBV were negative. Coagulation function and ADAMTS13 activity are normal. Respiratory viral panel positive for rhinovirus. Bone marrow biopsy indicates trilineage maturing hematopoiesis with increased megakaryocytes, and unremarkable flow cytometry and cytogenetic analysis. Imaging shows a small focus of hemorrhage into a pituitary macroadenoma, indicative of pituitary apoplexy.", "assessment": "The primary diagnosis is Immune Thrombocytopenic Purpura (ITP), likely triggered by a recent rhinovirus infection. The patient also developed pituitary apoplexy, a complication from treatment. Differential diagnoses were ruled out through extensive testing.", "plan": "Treatment initiated with IV dexamethasone 40 mg daily for 4 days and IVIG 1 g/kg/day on hospital days 4 and 5. Following the development of pituitary apoplexy, intravenous aminocaproic acid was started. Daily platelet transfusions were ineffective, and romiplostim was administered on hospital days 7 and 14. Anti-D was not used due to the patient's Rh-negative blood type. Transitioned from dexamethasone to prednisone 1 mg/kg/day with a tapering plan. An uncomplicated laparoscopic splenectomy was performed on hospital day 18 due to persistent low platelet counts. The patient is advised to continue close monitoring and follow-up to ensure recovery and adjust treatment as necessary."}
# ```<|im_end|>
#
# [INFO|configuration_utils.py:696] 2025-05-07 12:37:01,428 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-07 12:37:01,429 >> Model config Qwen2Config {
#   "_name_or_path": "Qwen/Qwen2.5-1.5B-Instruct",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|2025-05-07 12:37:01] llamafactory.model.model_utils.kv_cache:143 >> KV cache is disabled during training.
# model.safetensors: 100% 3.09G/3.09G [00:43<00:00, 70.3MB/s]
# [INFO|modeling_utils.py:3904] 2025-05-07 12:37:46,208 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/model.safetensors
# [INFO|modeling_utils.py:1582] 2025-05-07 12:37:46,248 >> Instantiating Qwen2ForCausalLM model under default dtype torch.float16.
# [INFO|configuration_utils.py:1140] 2025-05-07 12:37:46,252 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "use_cache": false
# }
#
# [INFO|modeling_utils.py:4888] 2025-05-07 12:37:51,346 >> All model checkpoint weights were used when initializing Qwen2ForCausalLM.
#
# [INFO|modeling_utils.py:4896] 2025-05-07 12:37:51,347 >> All the weights of Qwen2ForCausalLM were initialized from the model checkpoint at Qwen/Qwen2.5-1.5B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2ForCausalLM for predictions without further training.
# generation_config.json: 100% 242/242 [00:00<00:00, 1.83MB/s]
# [INFO|configuration_utils.py:1095] 2025-05-07 12:37:51,767 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/generation_config.json
# [INFO|configuration_utils.py:1140] 2025-05-07 12:37:51,768 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.1,
#   "temperature": 0.7,
#   "top_k": 20,
#   "top_p": 0.8
# }
#
# [INFO|2025-05-07 12:37:51] llamafactory.model.model_utils.checkpointing:143 >> Gradient checkpointing enabled.
# [INFO|2025-05-07 12:37:51] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2025-05-07 12:37:51] llamafactory.model.adapter:143 >> Upcasting trainable params to float32.
# [INFO|2025-05-07 12:37:51] llamafactory.model.adapter:143 >> Fine-tuning method: LoRA
# [INFO|2025-05-07 12:37:51] llamafactory.model.model_utils.misc:143 >> Found linear modules: v_proj,gate_proj,up_proj,o_proj,down_proj,k_proj,q_proj
# [INFO|2025-05-07 12:37:52] llamafactory.model.loader:143 >> trainable params: 18,464,768 || all params: 1,562,179,072 || trainable%: 1.1820
# [INFO|trainer.py:741] 2025-05-07 12:37:52,478 >> Using auto half precision backend
# [INFO|trainer.py:2775] 2025-05-07 12:37:52,929 >> Loading model from /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-600.
# [INFO|trainer.py:2369] 2025-05-07 12:38:07,911 >> ***** Running training *****
# [INFO|trainer.py:2370] 2025-05-07 12:38:07,911 >>   Num examples = 9,000
# [INFO|trainer.py:2371] 2025-05-07 12:38:07,911 >>   Num Epochs = 2
# [INFO|trainer.py:2372] 2025-05-07 12:38:07,911 >>   Instantaneous batch size per device = 1
# [INFO|trainer.py:2375] 2025-05-07 12:38:07,911 >>   Total train batch size (w. parallel, distributed & accumulation) = 16
# [INFO|trainer.py:2376] 2025-05-07 12:38:07,911 >>   Gradient Accumulation steps = 16
# [INFO|trainer.py:2377] 2025-05-07 12:38:07,911 >>   Total optimization steps = 843
# [INFO|trainer.py:2378] 2025-05-07 12:38:07,916 >>   Number of trainable parameters = 18,464,768
# [INFO|trainer.py:2400] 2025-05-07 12:38:07,919 >>   Continuing training from checkpoint, will skip to saved global_step
# [INFO|trainer.py:2401] 2025-05-07 12:38:07,919 >>   Continuing training from epoch 1
# [INFO|trainer.py:2402] 2025-05-07 12:38:07,919 >>   Continuing training from global step 600
# [INFO|trainer.py:2404] 2025-05-07 12:38:07,919 >>   Will skip the first 1 epochs then the first 608 batches in the first epoch.
# [INFO|integration_utils.py:817] 2025-05-07 12:38:07,924 >> Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: hazemwalied2003 (hazemwalied2003-cairo-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in /content/LLaMA-Factory/wandb/run-20250507_123808-fov0dmlh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run qwen-finetune-v2
# wandb: ⭐️ View project at https://wandb.ai/hazemwalied2003-cairo-university/llamafactory
# wandb: 🚀 View run at https://wandb.ai/hazemwalied2003-cairo-university/llamafactory/runs/fov0dmlh
# {'loss': 0.5705, 'grad_norm': 0.6330773234367371, 'learning_rate': 6.84312991667784e-06, 'epoch': 1.16}
# {'loss': 0.5703, 'grad_norm': 0.6691081523895264, 'learning_rate': 3.839360082333771e-06, 'epoch': 1.25}
# {'loss': 0.5597, 'grad_norm': 0.6593057513237, 'learning_rate': 1.6487817730020365e-06, 'epoch': 1.33}
# {'loss': 0.5611, 'grad_norm': 0.6235556602478027, 'learning_rate': 3.555776846197817e-07, 'epoch': 1.42}
#  95% 800/843 [1:03:31<13:39, 19.06s/it][INFO|trainer.py:4226] 2025-05-07 13:41:41,119 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4228] 2025-05-07 13:41:41,119 >>   Num examples = 1000
# [INFO|trainer.py:4231] 2025-05-07 13:41:41,119 >>   Batch size = 1
#
#   0% 0/1000 [00:00<?, ?it/s]
#   0% 2/1000 [00:00<03:17,  5.06it/s]
#   0% 3/1000 [00:00<04:18,  3.85it/s]
#   0% 4/1000 [00:01<04:49,  3.45it/s]
#   0% 5/1000 [00:01<05:10,  3.21it/s]
#   1% 6/1000 [00:01<05:42,  2.90it/s]
#   1% 7/1000 [00:02<05:50,  2.84it/s]
#   1% 8/1000 [00:02<05:45,  2.87it/s]
#   1% 9/1000 [00:02<05:43,  2.89it/s]
#   1% 10/1000 [00:03<06:02,  2.73it/s]
#   1% 11/1000 [00:03<06:00,  2.74it/s]
#   1% 12/1000 [00:04<06:08,  2.68it/s]
#   1% 13/1000 [00:04<05:37,  2.92it/s]
#   1% 14/1000 [00:04<05:45,  2.86it/s]
#   2% 15/1000 [00:05<05:49,  2.82it/s]
#   2% 16/1000 [00:05<06:12,  2.64it/s]
#   2% 17/1000 [00:05<06:09,  2.66it/s]
#   2% 18/1000 [00:06<05:54,  2.77it/s]
#   2% 19/1000 [00:06<05:53,  2.77it/s]
#   2% 20/1000 [00:06<05:53,  2.77it/s]
#   2% 21/1000 [00:07<05:45,  2.83it/s]
#   2% 22/1000 [00:07<05:39,  2.88it/s]
#   2% 23/1000 [00:07<05:46,  2.82it/s]
#   2% 24/1000 [00:08<05:50,  2.79it/s]
#   2% 25/1000 [00:08<06:03,  2.68it/s]
#   3% 26/1000 [00:09<05:50,  2.78it/s]
#   3% 27/1000 [00:09<05:41,  2.85it/s]
#   3% 28/1000 [00:09<05:26,  2.97it/s]
#   3% 29/1000 [00:10<05:35,  2.89it/s]
#   3% 30/1000 [00:10<05:39,  2.86it/s]
#   3% 31/1000 [00:10<05:57,  2.71it/s]
#   3% 32/1000 [00:11<05:56,  2.71it/s]
#   3% 33/1000 [00:11<05:56,  2.71it/s]
#   3% 34/1000 [00:11<05:51,  2.75it/s]
#   4% 35/1000 [00:12<05:53,  2.73it/s]
#   4% 36/1000 [00:12<05:53,  2.73it/s]
#   4% 37/1000 [00:13<06:01,  2.66it/s]
#   4% 38/1000 [00:13<05:56,  2.70it/s]
#   4% 39/1000 [00:13<05:53,  2.72it/s]
#   4% 40/1000 [00:14<05:36,  2.85it/s]
#   4% 41/1000 [00:14<05:21,  2.98it/s]
#   4% 42/1000 [00:14<05:15,  3.03it/s]
#   4% 43/1000 [00:15<05:10,  3.08it/s]
#   4% 44/1000 [00:15<05:25,  2.94it/s]
gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-843
# [INFO|configuration_utils.py:696] 2025-05-07 14:01:18,087 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-07 14:01:18,088 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2491] 2025-05-07 14:01:18,373 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-843/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-07 14:01:18,379 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-843/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2491] 2025-05-07 14:01:19,566 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-07 14:01:19,571 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/special_tokens_map.json
# [INFO|trainer.py:2643] 2025-05-07 14:01:20,087 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 4992.1718, 'train_samples_per_second': 2.704, 'train_steps_per_second': 0.169, 'train_loss': 0.16335438494156265, 'epoch': 1.5}
# 100% 843/843 [1:23:10<00:00,  5.92s/it]
# [INFO|trainer.py:4691] 2025-05-07 14:01:20,097 >> Waiting for the current checkpoint push to be finished, this might take a couple of minutes.
# [INFO|trainer.py:3910] 2025-05-07 14:01:40,802 >> Saving model checkpoint to /gdrive/MyDrive/qwen-finetune-v2/models/
# [INFO|configuration_utils.py:696] 2025-05-07 14:01:41,032 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-07 14:01:41,033 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2491] 2025-05-07 14:01:41,362 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-07 14:01:41,368 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/special_tokens_map.json
# [INFO|trainer.py:3910] 2025-05-07 14:01:41,728 >> Saving model checkpoint to /gdrive/MyDrive/qwen-finetune-v2/models/
# [INFO|configuration_utils.py:696] 2025-05-07 14:01:42,238 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B-Instruct/snapshots/989aa7980e4cf806f80c7fef2b1adb7bc71aa306/config.json
# [INFO|configuration_utils.py:768] 2025-05-07 14:01:42,240 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 1536,
#   "initializer_range": 0.02,
#   "intermediate_size": 8960,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 21,
#   "model_type": "qwen2",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.48.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2491] 2025-05-07 14:01:42,940 >> tokenizer config file saved in /gdrive/MyDrive/qwen-finetune-v2/models/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2500] 2025-05-07 14:01:42,956 >> Special tokens file saved in /gdrive/MyDrive/qwen-finetune-v2/models/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =      1.4996
#   total_flos               = 129543847GF
#   train_loss               =      0.1634
#   train_runtime            =  1:23:12.17
#   train_samples_per_second =       2.704
#   train_steps_per_second   =       0.169
# Figure saved at: /gdrive/MyDrive/qwen-finetune-v2/models/training_loss.png
# Figure saved at: /gdrive/MyDrive/qwen-finetune-v2/models/training_eval_loss.png
# [WARNING|2025-05-07 14:01:46] llamafactory.extras.ploting:148 >> No metric eval_accuracy to plot.
# [INFO|trainer.py:4226] 2025-05-07 14:01:46,537 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4228] 2025-05-07 14:01:46,537 >>   Num examples = 1000
# [INFO|trainer.py:4231] 2025-05-07 14:01:46,537 >>   Batch size = 1
#  34% 341/1000 [02:01<04:10,  2.63it/s]

# %% [markdown]
# # Testing the Fine-tuned Model
# Now let's test our fine-tuned model on some examples.

# %%
# !pip install -U bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.1 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.5

# %%
import os
import torch
from peft import PeftModel
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# Set up offload directory
offload_dir = "/tmp/offload_dir"
os.makedirs(offload_dir, exist_ok=True)

# Specify the checkpoint path
adapter_path = "/gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-843"
print(f"Using adapter from checkpoint: {adapter_path}")

# Base model ID
base_model_id = "Qwen/Qwen2.5-1.5B-Instruct"
print(f"Using base model: {base_model_id}")

# Setup quantization config to reduce memory usage
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True
)

# Load base model with quantization
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    offload_folder=offload_dir,
    torch_dtype=torch.float16
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model_id)

# Load adapter weights
model = PeftModel.from_pretrained(model, adapter_path)

print("Model loaded successfully!")
# Out:
# Using adapter from checkpoint: /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-843
# Using base model: Qwen/Qwen2.5-1.5B-Instruct
# Model loaded successfully!

# %% [markdown]
# # Create Helper Function for SOAP Generation
# We'll create a utility function to generate SOAP notes with our fine-tuned model.

# %%
def generate_soap_summary(dialogue, max_tokens=2048):
    messages = [
    {
        "role": "system",
        "content": system_message
    },
    {
        "role": "user",
        "content": "\n".join([
            "# Patient-Doctor Dialogue:",
            dialogue,
            "",
            "# Task:",
            "Generate a structured SOAP summary from the above medical dialogue.",
            "The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.",
            "",
            "# JSON Schema:",
            json.dumps(SOAPSummary.model_json_schema(), ensure_ascii=False),
            "",
            "# SOAP Summary:",
            "```json"
        ])
    }
]

    # Apply prompt formatting
    text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    model_inputs = tokenizer([text], return_tensors="pt", padding=True).to(model.device)

    with torch.no_grad():
        generated_ids = model.generate(
            model_inputs.input_ids,
            max_new_tokens=max_tokens,
            do_sample=False
        )

    # Trim prompt from output
    generated_ids = [
        output_ids[len(input_ids):]
        for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    return tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]



dialogue = dataset['train'][508]['dialogue']
# Print a short preview of the dialogue
print(f"Dialogue preview: {dialogue}...\n")

# Generate and print the summary
summary = generate_soap_summary(dialogue)
print("Generated SOAP Summary:")
print(summary)
print("-" * 80)
# Out:
# Dialogue preview: Doctor: Hello, can you please tell me your medical history and any medications you are currently taking?
# Patient: Hi, I'm a 50-year-old woman with a history of HIV and I've been non-compliant with my highly active antiretroviral therapy (HAART).
# Doctor: Oh, I see. What brings you here today?
# Patient: I've been experiencing confusion, fevers, fatigue, and night sweats for about a month now.
# Doctor: Thank you for sharing that. We've conducted some laboratory tests during your admission. The findings show that your hemoglobin is at 4.6 g/dL, lactate at 2.8, and INR at 3.9. Your liver function tests (LFTs) are normal. Your CD4 count is low at 51/mm3, but your HIV viral load is less than 20 and your leukocyte count is normal.
# Patient: Oh, okay. So, what does that mean?
# Doctor: Well, we've given you blood transfusions to help with your low hemoglobin and hematocrit levels, but we haven't been able to identify a source of bleeding. Meanwhile, you've been febrile and hypotensive despite being treated with piperacillin-tazobactam, vancomycin, trimethoprim-sulfamethoxazole, and acyclovir. Your cultures have not shown any specific cause, but you did develop a Clostridium difficile infection on day 4 of your hospitalization.
# Patient: That sounds concerning. What happened next?
# Doctor: On day 6, you were transferred to the medical ICU and required vasopressors. We intubated you due to worsening encephalopathy. An MRI of your brain suggested HIV encephalitis, and an abdominal CT showed splenomegaly and multiple hypodense lesions in your liver and spleen.
# Patient: And what about my kidneys?
# Doctor: You developed progressive oliguric renal failure, and we initiated hemodialysis on day 9. We also found 64,000 copies of EBV DNA per mL in your blood, and your serum ferritin was elevated at 2,512 ng/mL. Your platelet counts gradually dropped to 17,000/uL from normal levels.
# Patient: So, what's the treatment for all this?
# Doctor: We suspected hemophagocytic lymphohistiocytosis (HLH) but didn't initiate treatment immediately because you only met four of the eight diagnostic criteria. However, on day 11, a bone marrow biopsy confirmed the presence of hemophagocytic cells, so we started you on the HLH-94 protocol with etoposide and dexamethasone.
# Patient: Did the treatment help?
# Doctor: Unfortunately, your hypotension, acidosis, and renal failure worsened. You didn't tolerate hemodialysis despite vasopressor support. At this point, the family decided to withdraw care.
# Patient's Family: What happens now?
# Doctor: I'm sorry to say that the patient passed away on day 12. The autopsy report also revealed evidence of Hodgkin's lymphoma in the liver and spleen, which was a new diagnosis. Our deepest condolences to you and your family....
#
# Generated SOAP Summary:
# {"subjective": "A 50-year-old female with a history of HIV presents with confusion, fevers, fatigue, and night sweats for approximately one month. She reports non-compliance with her HAART regimen. Her medical history includes complications related to HIV and recent infections including a Clostridium difficile infection and possible Hodgkin's lymphoma.", "objective": "Current lab results show hemoglobin at 4.6 g/dL, lactate at 2.8 mmol/L, INR at 3.9, normal liver function tests, low CD4 count at 51/mm3, and undetectable HIV viral load. No significant improvement in symptoms or stabilization of conditions post-transfusion and antibiotic treatments. Recent imaging indicated splenomegaly and multiple hypodense lesions in the liver and spleen. Brain MRI suggested HIV encephalitis. Renal failure was noted with progressively decreasing platelets and increased ferritin levels. Bone marrow biopsy confirmed hemophagocytic cells.", "assessment": "Primary diagnosis of HIV encephalitis complicated by severe immunodeficiency leading to opportunistic infections and organ damage. Differential diagnoses included other causes of immune suppression and neurological involvement such as HLH, although definitive confirmation came from the bone marrow biopsy. Complications included severe bacterial and fungal infections, acute kidney injury, and potential malignancy (Hodgkin's lymphoma).", "plan": "Management included supportive care with blood transfusions, antibiotics, and anti-inflammatory agents. Intensive monitoring and aggressive intervention were necessary due to the severity of underlying conditions. Despite intensive care efforts, the patient's condition deteriorated rapidly, leading to withdrawal of care. Palliative care was considered but declined. The case highlights the complexity and unpredictability of HIV-related complications."}
# ```
# --------------------------------------------------------------------------------

# %% [markdown]
# # Cost Estimation for Inference
# Let's estimate the computational cost of running inference with our model.

# %%
from tqdm.auto import tqdm
import random
from faker import Faker
from datetime import datetime
import torch

# Initialize Faker
fake = Faker()
start_time = datetime.now()

# Start tracking tokens
input_tokens = 0
output_tokens = 0

num_samples = 30

for i in tqdm(range(num_samples)):
    # Generate random text using Faker
    dialogue = fake.text(max_nb_chars=random.randint(400, 800))

    # Create the messages
    messages = [
    {
        "role": "system",
        "content": system_message
    },
    {
        "role": "user",
        "content": "\n".join([
            "# Patient-Doctor Dialogue:",
            dialogue,
            "",
            "# Task:",
            "Generate a structured SOAP summary from the above medical dialogue.",
            "The summary should include Subjective, Objective, Assessment, and Plan sections in JSON format.",
            "",
            "# JSON Schema:",
            json.dumps(SOAPSummary.model_json_schema(), ensure_ascii=False),
            "",
            "# SOAP Summary:",
            "```json"
        ])
    }
]

    # Get the input token count
    input_text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    current_input_tokens = len(tokenizer.encode(input_text))
    input_tokens += current_input_tokens

    # Generate the response
    response = generate_soap_summary(dialogue)

    # Get the output token count
    current_output_tokens = len(tokenizer.encode(response))
    output_tokens += current_output_tokens

    if i < 3:  # Just show stats for first few samples
        print(f"\nSample {i+1}:")
        print(f"  Random text length (chars): {len(dialogue)}")
        print(f"  Input tokens: {current_input_tokens}")
        print(f"  Output tokens: {current_output_tokens}")
        print(f"  Ratio (output/input): {current_output_tokens/current_input_tokens:.2f}")

# Calculate totals
total_time = (datetime.now() - start_time).total_seconds()
total_tokens = input_tokens + output_tokens

print(f"\n--- Cost Estimation Summary ---")
print(f"Total Processing Time: {total_time:.2f} seconds")
print(f"Average Time Per Sample: {total_time/num_samples:.2f} seconds")
print(f"Input Tokens: {input_tokens} (Average: {input_tokens/num_samples:.1f} per sample)")
print(f"Output Tokens: {output_tokens} (Average: {output_tokens/num_samples:.1f} per sample)")
print(f"Total Tokens: {total_tokens} (Average: {total_tokens/num_samples:.1f} per sample)")
print(f"Output/Input Token Ratio: {output_tokens/input_tokens:.2f}")

# Estimated cost calculation
input_cost_per_1k = 0.0015  # Example rate: $0.0015 per 1K input tokens
output_cost_per_1k = 0.002  # Example rate: $0.002 per 1K output tokens

estimated_input_cost = (input_tokens / 1000) * input_cost_per_1k
estimated_output_cost = (output_tokens / 1000) * output_cost_per_1k
total_estimated_cost = estimated_input_cost + estimated_output_cost

print(f"\n--- Estimated Costs (using example rates) ---")
print(f"Input Cost: ${estimated_input_cost:.4f}")
print(f"Output Cost: ${estimated_output_cost:.4f}")
print(f"Total Estimated Cost: ${total_estimated_cost:.4f}")
print(f"Cost Per Sample: ${total_estimated_cost/num_samples:.4f}")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Sample 1:
#   Random text length (chars): 594
#   Input tokens: 418
#   Output tokens: 271
#   Ratio (output/input): 0.65
#
# Sample 2:
#   Random text length (chars): 394
#   Input tokens: 382
#   Output tokens: 263
#   Ratio (output/input): 0.69
#
# Sample 3:
#   Random text length (chars): 572
#   Input tokens: 413
#   Output tokens: 292
#   Ratio (output/input): 0.71
#
# --- Cost Estimation Summary ---
# Total Processing Time: 850.57 seconds
# Average Time Per Sample: 28.35 seconds
# Input Tokens: 12257 (Average: 408.6 per sample)
# Output Tokens: 7464 (Average: 248.8 per sample)
# Total Tokens: 19721 (Average: 657.4 per sample)
# Output/Input Token Ratio: 0.61
#
# --- Estimated Costs (using example rates) ---
# Input Cost: $0.0184
# Output Cost: $0.0149
# Total Estimated Cost: $0.0333
# Cost Per Sample: $0.0011

# %%
print("No. of Tokens per second = "+str(total_tokens/total_time))
# Out:
# No. of Tokens per second = 23.185498899942072

# %% [markdown]
# # Pushing Model to **HuggingFace** Hub
# Now we'll push our fine-tuned model to the Hugging Face Hub for easy sharing and deployment.

# %%
# !pip install -q peft huggingface_hub

# %%
# Log in to Hugging Face
from huggingface_hub import login
from google.colab import userdata

hf_token = userdata.get('huggingface')
login(token=hf_token)

# %%
# Load the base model
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define model paths
base_model_id = "Qwen/Qwen2.5-1.5B-Instruct"
print(f"Loading base model: {base_model_id}")

# Load the model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto"
)

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model_id)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading base model: Qwen/Qwen2.5-1.5B-Instruct
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]

# %%
# Load the adapter
from peft import PeftModel

# Path to your fine-tuned adapter
adapter_path = "/gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-843"
print(f"Loading adapter from: {adapter_path}")

# Load the adapter onto the base model
model = PeftModel.from_pretrained(base_model, adapter_path)
# Out:
# Loading adapter from: /gdrive/MyDrive/qwen-finetune-v2/models/checkpoint-843

# %%
# Merge the adapter weights with the base model
print("Merging adapter with base model...")
merged_model = model.merge_and_unload()
# Out:
# Merging adapter with base model...

# %%
# Create a model card
import os

# Your Hugging Face username and model name
your_username = "hazem74"
model_name = "qwen-soap-summary-v2"
hf_model_repo = f"{your_username}/{model_name}"

# Create a model card
model_card = f"""
---
language:
- en
tags:
- medical
- healthcare
- SOAP notes
- clinical documentation
license: mit
datasets:
- omi-health/medical-dialogue-to-soap-summary
---

# DeepSeek SOAP Summary Generator

This model is fine-tuned to generate SOAP (Subjective, Objective, Assessment, Plan) summaries from patient-doctor dialogues.

## Usage

```python
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained("{hf_model_repo}", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("{hf_model_repo}")

# Sample dialogue
dialogue = \"\"\"
Doctor: Hello, how are you feeling today?
Patient: I've been having some chest pain for the last two days.
Doctor: Can you describe the pain?
Patient: It's a sharp pain, mostly on the left side.
\"\"\"

# Format the prompt
system_message = "You are a medical professional tasked with creating SOAP notes from patient-doctor dialogues."
user_content = f\"\"\"
# Patient-Doctor Dialogue:
{{dialogue}}

# Task:
Generate a SOAP summary from the above medical dialogue.
The summary should include Subjective, Objective, Assessment, and Plan sections.

# SOAP Summary:
\"\"\"

messages = [
    {{"role": "system", "content": system_message}},
    {{"role": "user", "content": user_content}}
]

# Generate SOAP summary
prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

outputs = model.generate(
    inputs.input_ids,
    max_new_tokens=512,
    temperature=0.3,
    top_p=0.9
)

soap_summary = tokenizer.decode(outputs[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
print(soap_summary)```

Limitations
This model assists healthcare professionals but should not replace human judgment. Always review generated summaries for accuracy.
"""

# %%
# Create a temporary directory and save the model
temp_dir = "/tmp/merged_model"
os.makedirs(temp_dir, exist_ok=True)

print(f"Saving merged model to {temp_dir}")
merged_model.save_pretrained(temp_dir, safe_serialization=True)
tokenizer.save_pretrained(temp_dir)

# Save the model card
with open(os.path.join(temp_dir, "README.md"), "w") as f:
    f.write(model_card)
# Out:
# Saving merged model to /tmp/merged_model

# %%
# Push the model to Hugging Face Hub
from huggingface_hub import HfApi

api = HfApi()
print(f"Pushing model to Hugging Face Hub: {hf_model_repo}")

# Create the repository if it doesn't exist
try:
    api.create_repo(repo_id=hf_model_repo, private=True, exist_ok=True)
    print(f"Repository {hf_model_repo} is ready")
except Exception as e:
    print(f"Note: {e}")

# Upload all files
print("Uploading files...")
api.upload_folder(
    folder_path=temp_dir,
    repo_id=hf_model_repo,
    token=hf_token
)
# Out:
# Pushing model to Hugging Face Hub: hazem74/qwen-soap-summary-v2
# Repository hazem74/qwen-soap-summary-v2 is ready
# Uploading files...
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/hazem74/qwen-soap-summary-v2/commit/bc0c13b44a3afce4453677053cb0ac1c4572e929', commit_message='Upload folder using huggingface_hub', commit_description='', oid='bc0c13b44a3afce4453677053cb0ac1c4572e929', pr_url=None, repo_url=RepoUrl('https://huggingface.co/hazem74/qwen-soap-summary-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='hazem74/qwen-soap-summary-v2'), pr_revision=None, pr_num=None)

# %% [markdown]
# # Test the Model from HuggingFace
# Now we will test the Model after uploading it to HuggingFace hub

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Load once and reuse
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(hf_model_repo)
model = AutoModelForCausalLM.from_pretrained(
    hf_model_repo,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",
    trust_remote_code=True
)

# System message (keep it same as before)
system_message = "\n".join([
    "You are a medical professional tasked with creating structured SOAP notes from patient-doctor dialogues.",
    "Generate a comprehensive SOAP summary that includes Subjective, Objective, Assessment, and Plan sections.",
    "Your summary should be concise yet comprehensive, capturing all relevant medical information.",
    "Output must be in valid JSON format according to the provided schema.",
    "Do not include any text outside the JSON structure."
])
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
# Test dialogue
test_dialogue = """
Doctor: Good morning. What brings you in today?
Patient: Hi, Doctor. I’ve been having a persistent cough for about two weeks now. It gets worse at night, and sometimes I feel short of breath.
Doctor: I see. Any fever, chills, or chest pain?
Patient: No fever or chills, but I do get some mild chest discomfort when I cough a lot.
Doctor: Do you have a history of asthma or any allergies?
Patient: I have mild asthma, but it’s usually well-controlled. I use an inhaler only occasionally.
Doctor: Any recent exposure to someone who was sick?
Patient: Yes, my daughter had a cold last week.
Doctor: Have you noticed any wheezing or phlegm?
Patient: Yes, there’s some wheezing, especially at night, and I’ve been coughing up clear phlegm.
Doctor: How’s your appetite and energy level?
Patient: Appetite is okay, but I’ve been feeling a bit tired lately.
Doctor: Alright. I’ll listen to your lungs now... (examines patient) You have some mild wheezing in both lungs, more on the right side.
Patient: Is it serious?
Doctor: It sounds like an asthma flare-up possibly triggered by a viral infection. Your oxygen levels are normal, and there’s no sign of pneumonia.
Patient: Okay, what should I do?
Doctor: I’ll prescribe a short course of oral steroids and advise using your inhaler regularly for the next few days. Drink plenty of fluids and rest. If your breathing worsens, go to the ER immediately."""

sample_dialogue = dataset['train'][121]['dialogue']

summary = generate_soap_summary(test_dialogue)
#print(dataset['train'][121]['soap'])
print(summary)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.8` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:650: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `20` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# {"subjective": "The patient reports a persistent cough lasting approximately two weeks, worsening at night and causing shortness of breath. The patient also experiences mild chest discomfort during intense coughing. There is no fever or chills; however, mild chest discomfort and wheezing are noted. The patient has a history of mild asthma, which is generally well-controlled with occasional use of an inhaler. Recently, the patient's daughter contracted a cold, leading to potential cross-infection.", "objective": "Physical examination reveals mild wheezing predominantly on the right lung. Oxygen saturation is within normal limits. No evidence of pneumonia or other respiratory distress is observed. The patient's appetite is acceptable, though they report feeling slightly fatigued.", "assessment": "The primary diagnosis is an asthma exacerbation likely triggered by a viral infection, considering the presence of wheezing and the recent exposure to a cold. Differential diagnoses could include bronchitis or chronic obstructive pulmonary disease (COPD), although these are less likely given the acute nature and absence of typical COPD features such as increased sputum production.", "plan": "Prescribe a short course of oral steroids to manage inflammation and reduce airway hyperresponsiveness. Advise the patient to continue using their regular asthma inhaler regimen. Recommend increasing fluid intake and ensuring adequate rest. Monitor the patient closely for any deterioration in respiratory status or new symptoms. If symptoms persist or worsen despite treatment, immediate emergency room evaluation is recommended."}
# ```
